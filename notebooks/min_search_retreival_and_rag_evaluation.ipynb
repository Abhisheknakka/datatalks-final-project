# %%
# Import necessary libraries
import json
import pandas as pd
import openai
from groq import Groq
from dotenv import load_dotenv
import os
from sklearn.feature_extraction.text import CountVectorizer
from tqdm.auto import tqdm

# %%
# Load environment variables
load_dotenv()
# Out:
# True

# %%
# Setup project paths
base_folder = 'D:/Projects/datatalks-final-project/'
input_data_folder = base_folder + 'dataset/'

# %%
# Get the current working directory (optional step)
os.getcwd()
# Out:
# 'd:\\Projects\\datatalks-final-project\\notebooks'

# %%
# Setup the OpenAI client to use either Groq, OpenAI.com, or Ollama API
load_dotenv(override=True)
API_HOST = os.getenv("API_HOST")
API_HOST
# Out:
# 'groq'

# %%
if API_HOST == "groq":
    client = client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),
)
    MODEL_NAME = os.getenv("GROQ_MODEL")

elif API_HOST == "ollama":
    client = openai.OpenAI(
        base_url=os.getenv("OLLAMA_ENDPOINT"),
        api_key="nokeyneeded",
    )
    MODEL_NAME = os.getenv("OLLAMA_MODEL")

elif API_HOST == "openai":
    client = openai.OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
    MODEL_NAME = os.getenv("OPENAI_MODEL")
else:
    print("No LLM Selected")

# %%
client

# %%
MODEL_NAME
# Out:
# 'llama3-8b-8192'

# %%
with open(input_data_folder + 'main_faq_database.json', 'rt') as f_in:
    data = json.load(f_in)

# %%
documents = []
for dish in data['dishes']:
    dish_name = dish['dish name']
    for doc in dish['documents']:
        doc['dish_name'] = dish_name  # Add dish_name to each document
        documents.append(doc)

# %%
documents[1:3]
# Out:
# [{'id': '142_2',
#   'question': 'How many calories does it have?',
#   'section': 'calories',
#   'text': 'The almond fudge banana cake has 224.8 calories.',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_3',
#   'question': 'How much total fat does it contain?',
#   'section': 'nutritional',
#   'text': 'The almond fudge banana cake has N/A grams of total fat (PDV).',
#   'dish_name': 'almond fudge banana cake'}]

# %% [markdown]
# Retreival evaluation

# %%
import minsearch

index = minsearch.Index(
    text_fields = ['id', 'question','section','text','dish_name'],
    keyword_fields=['dish_name']
)

index.fit(documents)

# %%
#import ground truth dataset
import pandas as pd
ground_df = pd.read_csv(input_data_folder +'gold_standard_data/ground-truth-data.csv')

# %%
ground_truth = ground_df.to_dict(orient='records')

# %%
documents[1]
# Out:
# {'id': '142_2',
#  'question': 'How many calories does it have?',
#  'section': 'calories',
#  'text': 'The almond fudge banana cake has 224.8 calories.',
#  'dish_name': 'almond fudge banana cake'}

# %%
def hit_rate(relevance_total):
    cnt = 0

    for line in relevance_total:
        if True in line:
            cnt = cnt + 1

    return cnt / len(relevance_total)

# %%
def hit_rate2(relevance_total):
    cnt = sum([1 for line in relevance_total if any(line)])
    return cnt / len(relevance_total)

# %%
def mrr(relevance_total):
    total_score = 0.0

    for line in relevance_total:
        for rank in range(len(line)):
            if line[rank] == True:
                total_score = total_score + 1 / (rank + 1)

    return total_score / len(relevance_total)

# %%
def mrr2(relevance_total):
    total_score = 0.0

    for line in relevance_total:
        for rank, relevance in enumerate(line):
            if relevance:  # If relevant document is found
                total_score += 1 / (rank + 1)  # rank+1 because rank is 1-based
                break  # Stop after the first relevant document

    return total_score / len(relevance_total)

# %%
documents[1]
# Out:
# {'id': '142_2',
#  'question': 'How many calories does it have?',
#  'section': 'calories',
#  'text': 'The almond fudge banana cake has 224.8 calories.',
#  'dish_name': 'almond fudge banana cake'}

# %%
def minsearch_search(query):
    boost = {

    'question': 2.5,       # High priority: users are searching questions
    'dish_name': 1.7,      # Important for matching specific dishes
    'section': 1.2,        # Moderate boost: helps in filtering by category
    'text': 1.3        # Slight boost: could help match answer content}
    }

    results = index.search(
        query=query,
        filter_dict={'question': query},
        boost_dict=boost,
        num_results=10
    )

    return results

# %%
ground_df.head()
# Out:
#                                             question     id
# 0  Is almond fudge banana cake made with real ban...  142_1
# 1       Does almond fudge banana cake contain dairy?  142_1
# 2  Can I be sure there are no artificial flavors ...  142_1
# 3  Are the ingredients in almond fudge banana cak...  142_1
# 4  May I know the types of flour and sugar used i...  142_1

# %%
ground_truth = ground_df.to_dict(orient='records')

# %%
ground_truth[0]
# Out:
# {'question': 'Is almond fudge banana cake made with real bananas?',
#  'id': '142_1'}

# %%
def evaluate(ground_truth, search_function):
    relevance_total = []

    for q in tqdm(ground_truth):
        doc_id = q['id']
        results = search_function(q)
        relevance = [d['id'] == doc_id for d in results]
        relevance_total.append(relevance)

    return {
        'hit_rate': hit_rate(relevance_total),
        'mrr': mrr(relevance_total),
    }

# %%
from tqdm.auto import tqdm

# %%
evaluate(ground_truth, lambda q: minsearch_search(q['question']))
# Out:
#   0%|          | 0/16527 [00:00<?, ?it/s]
# {'hit_rate': 0.5956918981061293, 'mrr': 0.3399384220722044}

# %%
import pandas as pd

def visualize_search_results(ground_truth, search_function):
    # Create an empty list to store the results
    search_results = []

    # Iterate over each query in the ground truth dataset
    for q in tqdm(ground_truth):
        doc_id = q['id']
        ground_truth_question = q['question']
        
        # Perform the search using the provided function
        results = search_function(q['question'])
        
        # Collect the top result from the search
        if results:
            matched_question = results[0]['question']
            matched_doc_id = results[0]['id']
        else:
            matched_question = None
            matched_doc_id = None

        # Append the comparison of the ground truth with the top matched result
        search_results.append({
            'Ground Truth ID': doc_id,
            'Ground Truth Question': ground_truth_question,
            'Matched Document ID': matched_doc_id,
            'Matched Question': matched_question
        })

    # Convert the results into a Pandas DataFrame for visualization
    results_df = pd.DataFrame(search_results)
    
    # Display the DataFrame
    pd.set_option('display.max_colwidth', None)
    return results_df

# Visualize the search results
results_df = visualize_search_results(ground_truth, lambda q: minsearch_search(q))
print(results_df.head())

# Optionally, you can also save this as an Excel or CSV file for further inspection
results_df.to_csv('search_results_comparison.csv', index=False)
# Out:
#   0%|          | 0/16527 [00:00<?, ?it/s]
#   Ground Truth ID  \
# 0           142_1
# 1           142_1
# 2           142_1
# 3           142_1
# 4           142_1
#
#                                                         Ground Truth Question  \
# 0                         Is almond fudge banana cake made with real bananas?
# 1                                Does almond fudge banana cake contain dairy?
# 2  Can I be sure there are no artificial flavors in almond fudge banana cake?
# 3         Are the ingredients in almond fudge banana cake free from liqueurs?
# 4   May I know the types of flour and sugar used in almond fudge banana cake?
#
#   Matched Document ID                          Matched Question
# 0              142_11  What tags are associated with this dish?
# 1               142_3       How much total fat does it contain?
# 2               142_5          How much sodium is in this dish?
# 3               142_1                 What are the ingredients?
# 4               142_4                What is the sugar content?

# %%
ground_df.head(20)
# Out:
#                                                                       question  \
# 0                          Is almond fudge banana cake made with real bananas?
# 1                                 Does almond fudge banana cake contain dairy?
# 2   Can I be sure there are no artificial flavors in almond fudge banana cake?
# 3          Are the ingredients in almond fudge banana cake free from liqueurs?
# 4    May I know the types of flour and sugar used in almond fudge banana cake?
# 5                    How many calories does the Almond Fudge Banana Cake have?
# 6                  Can I get nutrition facts for the Almond Fudge Banana Cake?
# 7                   What's the calorie count for the Almond Fudge Banana Cake?
# 8                           How many calories is the Almond Fudge Banana Cake?
# 9                  What's the calorie content of the Almond Fudge Banana Cake?
# 10                        How much fat does the Almond Fudge Banana Cake have?
# 11              What is the total fat content of the Almond Fudge Banana Cake?
# 12                                Is the Almond Fudge Banana Cake high in fat?
# 13            Can I get the calorie breakdown of the Almond Fudge Banana Cake?
# 14                  How many grams of fat are in the Almond Fudge Banana Cake?
# 15                 How much sweetness comes from the almond fudge banana cake?
# 16                 What's the amount of sugar in the almond fudge banana cake?
# 17                              Is the almond fudge banana cake high in sugar?
# 18                 Can I know the sugar level of the almond fudge banana cake?
# 19  How much sugar is there in a standard serving of almond fudge banana cake?
#
#        id
# 0   142_1
# 1   142_1
# 2   142_1
# 3   142_1
# 4   142_1
# 5   142_2
# 6   142_2
# 7   142_2
# 8   142_2
# 9   142_2
# 10  142_3
# 11  142_3
# 12  142_3
# 13  142_3
# 14  142_3
# 15  142_4
# 16  142_4
# 17  142_4
# 18  142_4
# 19  142_4

# %%
documents[1:20]
# Out:
# [{'id': '142_2',
#   'question': 'How many calories does it have?',
#   'section': 'calories',
#   'text': 'The almond fudge banana cake has 224.8 calories.',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_3',
#   'question': 'How much total fat does it contain?',
#   'section': 'nutritional',
#   'text': 'The almond fudge banana cake has 14 grams of total fat (PDV).',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_4',
#   'question': 'What is the sugar content?',
#   'section': 'nutritional',
#   'text': 'The almond fudge banana cake has 87 grams of sugar (PDV).',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_5',
#   'question': 'How much sodium is in this dish?',
#   'section': 'nutritional',
#   'text': 'The almond fudge banana cake has 10 grams of sodium (PDV).',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_6',
#   'question': 'What is the protein content?',
#   'section': 'nutritional',
#   'text': 'The almond fudge banana cake has 7 grams of protein (PDV).',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_7',
#   'question': 'How much saturated fat is present?',
#   'section': 'nutritional',
#   'text': 'The almond fudge banana cake has 9 grams of saturated fat (PDV).',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_8',
#   'question': 'What are the carbohydrate levels?',
#   'section': 'nutritional',
#   'text': 'The almond fudge banana cake has 11 grams of carbohydrates (PDV).',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_9',
#   'question': 'How long does it take to prepare?',
#   'section': 'preparation',
#   'text': 'The almond fudge banana cake takes 110 minutes to prepare.',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_10',
#   'question': 'What are the steps to prepare this dish?',
#   'section': 'steps',
#   'text': "The almond fudge banana cake contains ['mash bananas and set aside', 'beat sugar and margarine until light and fluffy', 'beat in eggs , liqueur and vanilla', 'combine dry ingredients', 'stir in almonds', 'add to sugar mixture alternately with bananas', 'beat well', 'pour batter into greased 10-inch bundt pan', 'bake in preheated 350f oven 45 to 50 minutes or until toothpick inserted in center comes out almost clean and cake pulls away from side of pan', 'cool 10 minutes', 'remove cake from pan to wire rack to cool completely', 'drizzle glaze over top and down side of cake', 'make 16-20 servings']",
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_11',
#   'question': 'What tags are associated with this dish?',
#   'section': 'tags',
#   'text': "The almond fudge banana cake contains ['weeknight', 'time-to-make', 'course', 'preparation', 'for-large-groups', 'desserts', 'oven', 'cakes', 'dietary', 'equipment', 'number-of-servings', '4-hours-or-less']",
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_12',
#   'question': 'What is the rating of this dish?',
#   'section': 'rating',
#   'text': 'The almond fudge banana cake has a rating of 4.',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_13',
#   'question': 'Can you provide a review?',
#   'section': 'review',
#   'text': 'Review for almond fudge banana cake: Came out great for a chocolate Easter cake. I made an almond cream cheese frosting instead of a chocolate glaze to make it more Spring-like. Very moist and the banana is definately the strongest flavor coming from the cake. Will definately make again.',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_14',
#   'question': 'What category does this dish fall under?',
#   'section': 'category',
#   'text': 'The category of almond fudge banana cake is tasty.',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_15',
#   'question': 'What is the calorie status of this dish?',
#   'section': 'calorie_status',
#   'text': 'The calorie status of almond fudge banana cake is Low Calory.',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_16',
#   'question': 'What is the price of this dish?',
#   'section': 'price',
#   'text': 'The price of almond fudge banana cake is $24.',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '520_1',
#   'question': 'What are the ingredients?',
#   'section': 'ingredients',
#   'text': "The apple pie cake contains the following ingredients: ['sugar', 'egg', 'salt', 'butter', 'flour', 'baking powder', 'cinnamon', 'nutmeg', 'vanilla', 'baking apples', 'pecans', 'golden raisin']",
#   'dish_name': 'apple pie cake'},
#  {'id': '520_2',
#   'question': 'How many calories does it have?',
#   'section': 'calories',
#   'text': 'The apple pie cake has 359.1 calories.',
#   'dish_name': 'apple pie cake'},
#  {'id': '520_3',
#   'question': 'How much total fat does it contain?',
#   'section': 'nutritional',
#   'text': 'The apple pie cake has 26 grams of total fat (PDV).',
#   'dish_name': 'apple pie cake'},
#  {'id': '520_4',
#   'question': 'What is the sugar content?',
#   'section': 'nutritional',
#   'text': 'The apple pie cake has 136 grams of sugar (PDV).',
#   'dish_name': 'apple pie cake'}]

# %% [markdown]
# ## The RAG flow

# %%
def build_prompt(query, search_results):
    prompt_template = """
You're an AI assistant helping with menu queries. Answer the QUESTION based on the CONTEXT provided.

QUESTION: {question}

CONTEXT: 
{context}
""".strip()

    context = ""
    
    for doc in search_results:
        context += f"Section: {doc['section']}\nQuestion: {doc['question']}\nAnswer: {doc['text']}\n\n"
    
    prompt = prompt_template.format(question=query, context=context).strip()
    return prompt

# %%
client

# %%
def llm(prompt):
    response = client.chat.completions.create(
        model= MODEL_NAME,
        messages=[{"role": "user", "content": prompt}]
    )
    
    return response.choices[0].message.content

# %%
import minsearch

index = minsearch.Index(
    text_fields = ['id', 'question','section','text','dish_name'],
    keyword_fields=['dish_name']
    #keyword_fields=['id']
)

# %%
index.fit(documents)

# %%
import json
from time import time
from openai import OpenAI
import ingest
import json
import pandas as pd
from groq import Groq
from dotenv import load_dotenv
import os
from sklearn.feature_extraction.text import CountVectorizer
from tqdm.auto import tqdm

# Setup the OpenAI client to use either Groq, OpenAI.com, or Ollama API
load_dotenv()
API_HOST = os.getenv("API_HOST")


if API_HOST == "groq":
    client = client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),
)
    MODEL_NAME = os.getenv("GROQ_MODEL")

elif API_HOST == "ollama":
    client = openai.OpenAI(
        base_url=os.getenv("OLLAMA_ENDPOINT"),
        api_key="nokeyneeded",
    )
    MODEL_NAME = os.getenv("OLLAMA_MODEL")

elif API_HOST == "openai":
    client = openai.OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
    MODEL_NAME = os.getenv("OPENAI_MODEL")
else:
    print("No LLM Selected")


client = OpenAI()
index = ingest.load_index()


def minsearch_search(query):
    boost = {

    'question': 2.5,       # High priority: users are searching questions
    'dish_name': 1.7,      # Important for matching specific dishes
    'section': 1.2,        # Moderate boost: helps in filtering by category
    'text': 1.3        # Slight boost: could help match answer content}
    }

    results = index.search(
        query=query,
        filter_dict={'question': query},
        boost_dict=boost,
        num_results=10
    )

    return results


entry_template = """
question: {question}
dish_name: {dish_name}
section: {section}
text: {text}
""".strip()



prompt_template = """
You're an AI assistant helping with menu queries. Answer the QUESTION based on the CONTEXT from our database.
Use only the facts from the CONTEXT when answering the QUESTION.
QUESTION: {question}
CONTEXT: 
{context}
""".strip()


def build_prompt(query, search_results):
    context = ""
    
    for doc in search_results:
        #context += f"Section: {doc['section']}\nQuestion: {doc['question']}\nAnswer: {doc['text']}\n\n"
        context = context + entry_template.format(**doc) + "\n\n"

    prompt = prompt_template.format(question=query, context=context).strip()
    return prompt



def llm(prompt, model=MODEL_NAME):
    response = client.chat.completions.create(
        model= MODEL_NAME,
        messages=[{"role": "user", "content": prompt}]
    )
    
    #return response.choices[0].message.content
    answer = response.choices[0].message.content

    token_stats = {
        "prompt_tokens": response.usage.prompt_tokens,
        "completion_tokens": response.usage.completion_tokens,
        "total_tokens": response.usage.total_tokens,
    }

    return answer, token_stats

#def llm(prompt, model="gpt-4o-mini"):
    response = client.chat.completions.create(
        model=model, messages=[{"role": "user", "content": prompt}]
    )

    answer = response.choices[0].message.content

    token_stats = {
        "prompt_tokens": response.usage.prompt_tokens,
        "completion_tokens": response.usage.completion_tokens,
        "total_tokens": response.usage.total_tokens,
    }

    return answer, token_stats


evaluation_prompt_template = """
You are an expert evaluator for a RAG system.
Your task is to analyze the relevance of the generated answer to the given question.
Based on the relevance of the generated answer, you will classify it
as "NON_RELEVANT", "PARTLY_RELEVANT", or "RELEVANT".

Here is the data for evaluation:

Question: {question}
Generated Answer: {answer}

Please analyze the content and context of the generated answer in relation to the question
and provide your evaluation in parsable JSON without using code blocks:

{{
  "Relevance": "NON_RELEVANT" | "PARTLY_RELEVANT" | "RELEVANT",
  "Explanation": "[Provide a brief explanation for your evaluation]"
}}
""".strip()


def evaluate_relevance(question, answer):
    prompt = evaluation_prompt_template.format(question=question, answer=answer)
    evaluation, tokens = llm(prompt, model=MODEL_NAME)

    try:
        json_eval = json.loads(evaluation)
        return json_eval, tokens
    except json.JSONDecodeError:
        result = {"Relevance": "UNKNOWN", "Explanation": "Failed to parse evaluation"}
        return result, tokens


def calculate_openai_cost(model, tokens):
    openai_cost = 0

    if model == MODEL_NAME:
        openai_cost = (
            tokens["prompt_tokens"] * 0.00015 + tokens["completion_tokens"] * 0.0006
        ) / 1000
    else:
        print("Model not recognized. OpenAI cost calculation failed.")

    return openai_cost


def rag(query, model=MODEL_NAME):
    t0 = time()

    search_results = minsearch_search(query)
    prompt = build_prompt(query, search_results)
    answer, token_stats = llm(prompt, model=model)

    relevance, rel_token_stats = evaluate_relevance(query, answer)

    t1 = time()
    took = t1 - t0

    openai_cost_rag = calculate_openai_cost(model, token_stats)
    openai_cost_eval = calculate_openai_cost(model, rel_token_stats)

    openai_cost = openai_cost_rag + openai_cost_eval

    answer_data = {
        "answer": answer,
        "model_used": model,
        "response_time": took,
        "relevance": relevance.get("Relevance", "UNKNOWN"),
        "relevance_explanation": relevance.get(
            "Explanation", "Failed to parse evaluation"
        ),
        "prompt_tokens": token_stats["prompt_tokens"],
        "completion_tokens": token_stats["completion_tokens"],
        "total_tokens": token_stats["total_tokens"],
        "eval_prompt_tokens": rel_token_stats["prompt_tokens"],
        "eval_completion_tokens": rel_token_stats["completion_tokens"],
        "eval_total_tokens": rel_token_stats["total_tokens"],
        "openai_cost": openai_cost,
    }
    print("sic")
    return answer_data

# %%
def minsearch(question):
    return index.search(question)

# %%
def rag(query):
    search_results = minsearch(query)
    prompt=build_prompt(query,search_results)
    answer = llm(prompt)
    return answer

# %%
query = "what are the calories of white chocolate cake is it good?"
query = "what are the ingredients in white chocolate cake?"

rag(query)
# Out:
# 'Based on the provided context, the ingredients in the white chocolate cake are:\n\n* White chocolate\n* Butter\n* Sugar\n* Egg yolks\n* Vanilla\n* Cake flour\n* Baking powder\n* Salt\n* Buttermilk\n* Pecans\n* Flaked coconut\n* Egg whites\n* Flour\n* Milk\n\nLet me know if you need any further assistance!'

# %%
ground_truth[2]['question']
# Out:
# 'Can I be sure there are no artificial flavors in almond fudge banana cake?'

# %%
rag(ground_truth[1]['question'])
# Out:
# 'Based on the context, there is no specific mention of dairy in the provided sections (nutritional, category, calories, rating, preparation, price). Therefore, the answer to the question "Does almond fudge banana cake contain dairy?" is: "Not specified or listed." If you need to know if the cake contains dairy, you may want to check with the restaurant or bakery that serves it.'

# %% [markdown]
# ## RAG Evaluation - LLM as a judge

# %%
record = ground_truth[0]
question =  record['question']
answer_llm = rag(question)
answer_llm
# Out:
# 'Based on the provided CONTEXT, the answer to the QUESTION "Is almond fudge banana cake made with real bananas?" is:\n\nNot explicitly stated in the given context. However, the presence of the word "banana" in the name "almond fudge banana cake" suggests that bananas are likely an ingredient. Additionally, the presence of 11 grams of carbohydrates (PDV) and 87 grams of sugar (PDV) implies that bananas are likely used in the recipe. However, without direct confirmation, we can\'t be certain.'

# %%
prompt = prompt2_template.format(question=question,answer_llm=answer_llm)
prompt
# Out:
# 'You are an expert evaluator for a Retrieval-Augmented Generation (RAG) system.\nYour task is to analyze the relevance of the generated answer to the given question.\nBased on the relevance of the generated answer, you will classify it\nas "NON_RELEVANT", "PARTLY_RELEVANT", or "RELEVANT".\n\nHere is the data for evaluation:\n\nQuestion: Is almond fudge banana cake made with real bananas?\nGenerated Answer: Based on the provided CONTEXT, the answer to the QUESTION "Is almond fudge banana cake made with real bananas?" is:\n\nNot explicitly stated in the given context. However, the presence of the word "banana" in the name "almond fudge banana cake" suggests that bananas are likely an ingredient. Additionally, the presence of 11 grams of carbohydrates (PDV) and 87 grams of sugar (PDV) implies that bananas are likely used in the recipe. However, without direct confirmation, we can\'t be certain.\n\nPlease analyze the content and context of the generated answer in relation to the question\nand provide your evaluation in parsable JSON without using code blocks:\n\n{\n  "Relevance": "NON_RELEVANT" | "PARTLY_RELEVANT" | "RELEVANT",\n  "Explanation": "[Provide a brief explanation for your evaluation]"\n}'

# %%
record = ground_truth[0]
record
# Out:
# {'question': 'Is almond fudge banana cake made with real bananas?',
#  'id': '142_1'}

# %% [markdown]
# ## RAG EVALUATION

# %%
prompt2_template = """
You are an expert evaluator for a RAG system.
Your task is to analyze the relevance of the generated answer to the given question.
Based on the relevance of the generated answer, you will classify it
as "NON_RELEVANT", "PARTLY_RELEVANT", or "RELEVANT".

Here is the data for evaluation:

Question: {question}
Generated Answer: {answer_llm}

Please analyze the content and context of the generated answer in relation to the question
and provide your evaluation in parsable JSON without using code blocks:

{{
  "Relevance": "NON_RELEVANT" | "PARTLY_RELEVANT" | "RELEVANT",
  "Explanation": "[Provide a brief explanation for your evaluation]"
}}
""".strip()

# %%
len(ground_truth)
# Out:
# 16527

# %%
record = ground_truth[0]

# %%
print(answer_llm)
# Out:
# Based on the context provided, the answer to the question "What's the amount of sugar in the almond fudge banana cake?" is:
#
# 87 grams of sugar (PDV).

# %%
prompt = prompt2_template.format(question=question, answer_llm=answer_llm)
print(prompt)
# Out:
# You are an expert evaluator for a RAG system.
# Your task is to analyze the relevance of the generated answer to the given question.
# Based on the relevance of the generated answer, you will classify it
# as "NON_RELEVANT", "PARTLY_RELEVANT", or "RELEVANT".
#
# Here is the data for evaluation:
#
# Question: Is the almond fudge banana cake high in sugar?
# Generated Answer: Based on the context provided, the answer to the question "What's the amount of sugar in the almond fudge banana cake?" is:
#
# 87 grams of sugar (PDV).
#
# Please analyze the content and context of the generated answer in relation to the question
# and provide your evaluation in parsable JSON without using code blocks:
#
# {
#   "Relevance": "NON_RELEVANT" | "PARTLY_RELEVANT" | "RELEVANT",
#   "Explanation": "[Provide a brief explanation for your evaluation]"
# }

# %%
import json
len(ground_df)
# Out:
# 16527

# %%
df_sample = ground_df.sample(n=100, random_state=1)

# %%
sample  = df_sample.to_dict(orient='records')

# %%
df_sample
# Out:
#                                                                      question  \
# 3881                                  Are the cod cakes browned on both sides
# 15077          Can you tell me the preparation time for Coconut Shrimp Curry?
# 9392                                  Should I double the funnel cake recipe?
# 4398                        Tells me the calorie total for Streusel Plum Cake
# 15297                                  Milky Way Lover's Pound Cake prep time
# ...                                                                       ...
# 14559                                    Is the cheesecake cups low in carbs?
# 12518                  Can I get a step-by-step guide for caramel apple cake?
# 4108                                Easy Lemon Pound Cake preparation process
# 13302  Can I get an estimate for the timing on the chocolate angel food cake?
# 800                           What's the sequence for preparing Dirt Cake II?
#
#              id
# 3881   11252_10
# 15077   30898_9
# 9392   19611_13
# 4398    12105_2
# 15297   31334_9
# ...         ...
# 14559   30082_8
# 12518  26737_10
# 4108   11763_10
# 13302   28138_9
# 800     3333_10
#
# [100 rows x 2 columns]

# %%
for record in tqdm(sample):
    question = record['question']
    answer_llm = rag(question) 

    prompt = prompt2_template.format(
        question=question,
        answer_llm=answer_llm
    )

    evaluation = llm(prompt)

    # Log the evaluation to inspect if it's valid JSON
    print(f"Evaluation for question {question}: {evaluation}")

    try:
        # Try to parse the evaluation response as JSON
        evaluation = json.loads(evaluation)
    except json.JSONDecodeError as e:
        # Handle JSON decode errors gracefully
        print(f"JSONDecodeError for question {question}: {e}")
        evaluation = None  # You can decide what to do in case of error

    evaluations.append((record, answer_llm, evaluation))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluation for question Are the cod cakes browned on both sides: {
# "Relevance": "RELEVANT",
# "Explanation": "The generated answer provides a direct answer to the question 'Are the cod cakes browned on both sides?' by referencing the specific cooking instructions which include frying the patties for 4-5 minutes on each side. This provides a clear resolution to the question."
# JSONDecodeError for question Are the cod cakes browned on both sides: Expecting ',' delimiter: line 3 column 284 (char 310)
# Evaluation for question Can you tell me the preparation time for Coconut Shrimp Curry?: {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer acknowledges the question about preparation time for Coconut Shrimp Curry and provides an explanation for not being able to provide the answer, but also offers alternative solutions, indicating partial relevance to the question."
# JSONDecodeError for question Can you tell me the preparation time for Coconut Shrimp Curry?: Expecting ',' delimiter: line 3 column 269 (char 304)
# Evaluation for question Should I double the funnel cake recipe?: {
#   "Relevance": "NON_RELEVANT",
#   "Explanation": "The generated answer does not directly address the question 'Should I double the funnel cake recipe?' but instead discusses the recipe for Bacardi Double Chocolate Rum Cake and provides an unrelated suggestion for doubling the recipe."
# JSONDecodeError for question Should I double the funnel cake recipe?: Expecting ',' delimiter: line 3 column 254 (char 286)
# Evaluation for question Tells me the calorie total for Streusel Plum Cake: {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer is partly relevant because it acknowledges the question about the calorie total for Streusel Plum Cake, but instead of directly providing the answer, it provides a statement that the calorie status is 'Low Calory' without mentioning the actual calorie count for the Streusel Plum Cake. This partially addresses the question but does not provide the full answer."
# JSONDecodeError for question Tells me the calorie total for Streusel Plum Cake: Expecting ',' delimiter: line 3 column 402 (char 437)
# Evaluation for question Milky Way Lover's Pound Cake prep time: {
# "Relevance": "PARTLY_RELEVANT",
# "Explanation": "The generated answer mentions the Milky Way Lover's Pound Cake recipe, which is relevant to the question. However, it does not provide the prep time directly, only references it. Therefore, it's only partly relevant."
# JSONDecodeError for question Milky Way Lover's Pound Cake prep time: Expecting ',' delimiter: line 3 column 234 (char 267)
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# Cell In[73], line 10
#       3 answer_llm = rag(question)
#       5 prompt = prompt2_template.format(
#       6     question=question,
#       7     answer_llm=answer_llm
#       8 )
# ---> 10 evaluation = llm(prompt)
#      12 # Log the evaluation to inspect if it's valid JSON
#      13 print(f"Evaluation for question {question}: {evaluation}")
#
# Cell In[28], line 2, in llm(prompt)
#       1 def llm(prompt):
# ----> 2     response = client.chat.completions.create(
#       3         model= MODEL_NAME,
#       4         messages=[{"role": "user", "content": prompt}]
#       5     )
#       7     return response.choices[0].message.content
#
# File c:\Users\nakka\AppData\Local\Programs\Python\Python312\Lib\site-packages\groq\resources\chat\completions.py:289, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     148 def create(
#     149     self,
#     150     *,
#    (...)
#     177     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     178 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     179     """
#     180     Creates a model response for the given chat conversation.
#     181
#    (...)
#     287       timeout: Override the client-level default timeout for this request, in seconds
#     288     """
# --> 289     return self._post(
#     290         "/openai/v1/chat/completions",
#     291         body=maybe_transform(
#     292             {
#     293                 "messages": messages,
#     294                 "model": model,
#     295                 "frequency_penalty": frequency_penalty,
#     296                 "function_call": function_call,
#     297                 "functions": functions,
#     298                 "logit_bias": logit_bias,
#     299                 "logprobs": logprobs,
#     300                 "max_tokens": max_tokens,
#     301                 "n": n,
#     302                 "parallel_tool_calls": parallel_tool_calls,
#     303                 "presence_penalty": presence_penalty,
#     304                 "response_format": response_format,
#     305                 "seed": seed,
#     306                 "stop": stop,
#     307                 "stream": stream,
#     308                 "temperature": temperature,
#     309                 "tool_choice": tool_choice,
#     310                 "tools": tools,
#     311                 "top_logprobs": top_logprobs,
#     312                 "top_p": top_p,
#     313                 "user": user,
#     314             },
#     315             completion_create_params.CompletionCreateParams,
#     316         ),
#     317         options=make_request_options(
#     318             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     319         ),
#     320         cast_to=ChatCompletion,
#     321         stream=stream or False,
#     322         stream_cls=Stream[ChatCompletionChunk],
#     323     )
#
# File c:\Users\nakka\AppData\Local\Programs\Python\Python312\Lib\site-packages\groq\_base_client.py:1225, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1211 def post(
#    1212     self,
#    1213     path: str,
#    (...)
#    1220     stream_cls: type[_StreamT] | None = None,
#    1221 ) -> ResponseT | _StreamT:
#    1222     opts = FinalRequestOptions.construct(
#    1223         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1224     )
# -> 1225     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\nakka\AppData\Local\Programs\Python\Python312\Lib\site-packages\groq\_base_client.py:920, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     911 def request(
#     912     self,
#     913     cast_to: Type[ResponseT],
#    (...)
#     918     stream_cls: type[_StreamT] | None = None,
#     919 ) -> ResponseT | _StreamT:
# --> 920     return self._request(
#     921         cast_to=cast_to,
#     922         options=options,
#     923         stream=stream,
#     924         stream_cls=stream_cls,
#     925         remaining_retries=remaining_retries,
#     926     )
#
# File c:\Users\nakka\AppData\Local\Programs\Python\Python312\Lib\site-packages\groq\_base_client.py:1003, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1001 if retries > 0 and self._should_retry(err.response):
#    1002     err.response.close()
# -> 1003     return self._retry_request(
#    1004         options,
#    1005         cast_to,
#    1006         retries,
#    1007         err.response.headers,
#    1008         stream=stream,
#    1009         stream_cls=stream_cls,
#    1010     )
#    1012 # If the response is streamed then we need to explicitly read the response
#    1013 # to completion before attempting to access the response text.
#    1014 if not err.response.is_closed:
#
# File c:\Users\nakka\AppData\Local\Programs\Python\Python312\Lib\site-packages\groq\_base_client.py:1051, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1047 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1048 # different thread if necessary.
#    1049 time.sleep(timeout)
# -> 1051 return self._request(
#    1052     options=options,
#    1053     cast_to=cast_to,
#    1054     remaining_retries=remaining,
#    1055     stream=stream,
#    1056     stream_cls=stream_cls,
#    1057 )
#
# File c:\Users\nakka\AppData\Local\Programs\Python\Python312\Lib\site-packages\groq\_base_client.py:1018, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1015         err.response.read()
#    1017     log.debug("Re-raising status error")
# -> 1018     raise self._make_status_error_from_response(err.response) from None
#    1020 return self._process_response(
#    1021     cast_to=cast_to,
#    1022     options=options,
#    (...)
#    1025     stream_cls=stream_cls,
#    1026 )
#
# InternalServerError: Error code: 503 - {'error': {'message': 'Service Unavailable', 'type': 'internal_server_error'}}

# %%
df_eval = pd.DataFrame(evaluations, columns=['record', 'answer', 'evaluation'])

df_eval['id'] = df_eval.record.apply(lambda d: d['id'])
df_eval['question'] = df_eval.record.apply(lambda d: d['question'])

df_eval['relevance'] = df_eval.evaluation.apply(lambda d: d['Relevance'])
df_eval['explanation'] = df_eval.evaluation.apply(lambda d: d['Explanation'])

del df_eval['record']
del df_eval['evaluation']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 6
#       3 df_eval['id'] = df_eval.record.apply(lambda d: d['id'])
#       4 df_eval['question'] = df_eval.record.apply(lambda d: d['question'])
# ----> 6 df_eval['relevance'] = df_eval.evaluation.apply(lambda d: d['Relevance'])
#       7 df_eval['explanation'] = df_eval.evaluation.apply(lambda d: d['Explanation'])
#       9 del df_eval['record']
#
# File c:\Users\nakka\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\nakka\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\nakka\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\nakka\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\nakka\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[59], line 6, in <lambda>(d)
#       3 df_eval['id'] = df_eval.record.apply(lambda d: d['id'])
#       4 df_eval['question'] = df_eval.record.apply(lambda d: d['question'])
# ----> 6 df_eval['relevance'] = df_eval.evaluation.apply(lambda d: d['Relevance'])
#       7 df_eval['explanation'] = df_eval.evaluation.apply(lambda d: d['Explanation'])
#       9 del df_eval['record']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
df_eval.relevance.value_counts(normalize=True)
# Out:
# relevance
# RELEVANT           0.38
# PARTLY_RELEVANT    0.36
# NON_RELEVANT       0.26
# Name: proportion, dtype: float64

# %%
df_eval.to_csv(input_data_folder+'rag-eval-gpt-3.5-turbo.csv', index=False)

# %%
df_eval[df_eval.relevance == 'RELEVANT']
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                answer  \
# 0                                                                                                                                                                                                                                                                                                              The cod cakes are fried in a skillet for 4-5 minutes on each side until they are golden brown, so yes, they are browned on both sides.
# 4                                                                                                                                                                                                                                                                                        Section: prep_time\nQuestion: What is the prep time for Milky Way Lover's Pound Cake?\nAnswer: The prep time for Milky Way Lover's Pound Cake is 30 minutes.
# 7                                                                                                                                                                                                                                                                                                                                                   No, the rhubarb stir cake does not have a high carb count. It contains 17 grams of carbohydrates.
# 9                                                                                                                                                                                                                                                                                Section: nutritional\nQuestion: What is the fat content of the key lime cheesecake squares?\nAnswer: The key lime cheesecake squares has 6 grams of total fat (PDV).
# 11                                                                                     Instruction for baking the 1 Pan Fudge Cake:\n1. Preheat oven to 350 degrees\n2. In an ungreased 9 x 13 pan (yes ungreased), sift all dry ingredients\n3. Add the liquids and stir just until blended\n4. Bake for 25 minutes\n5. Frost with your favorite frosting, cake is extremely moist so care must be taken that you don't tear up the top of the cake.
# 13                                                                                                                                                                                                     Section: ingredients\nQuestion: Tell me the Million Dollar Pound Cake's composition?\nAnswer: The million dollar pound cake contains the following ingredients: butter, sugar, eggs, all-purpose flour, milk, almond extract, vanilla extract.
# 14                                                                                                                                                                                                                                                                                                                     Yes, based on the nutritional information provided, carrot snack cake is likely a sweet dish as it contains 46 grams of sugar.
# 18                                                                                                                                                                                                                                                                                                                                                       No, the Momma's Fair Funnel Cake is not high in salt as it only contains 16 grams of sodium.
# 21                                                                                                                                                                                                                                                                                                                                                                                        The peach upside down pudding cake contains 413.0 calories.
# 23                                                                                                                                                                                                                                                                                                                                                                               Flavor profile: The 7 up pound cake has a lemon-lime flavor profile.
# 24                                                                                                                                                                                                                                                   QUESTION: What's the secret to achieving the Depression Fudge cake's rich color?\n\nANSWER: The secret to achieving the rich color of the Depression Fudge cake is the cocoa used in the recipe.
# 25                                                                                                                                                                                                                                                          Section: nutritional\nQuestion: What is the sodium level in the flourless chocolate oh so good molten cake?\nAnswer: The flourless chocolate oh so good molten cake has 1 gram of sodium.
# 27                                                                                                                                                                               Question: Would I gain weight eating Hand Me Down Chocolate Cake?\n\nAnswer: Based on the nutritional information provided, the hand me down chocolate cake is high in total fat, saturated fat, and calories. Consuming it regularly may contribute to weight gain.
# 28                                                                                                                                                                                                                                                                                                                              Section: nutritional\nQuestion: What is the sugar content?\nAnswer: The cheesecake kugel has 36 grams of sugar (PDV).
# 31  QUESTION: How does the original frosting compare to other frosting options for German Chocolate Cake?\n\nAnswer: The German Chocolate Cake frosting is the original topping for this specific cake and is a traditional favorite. It is known for its rich, sweet, and coconut-pecan flavor profile. Other frosting options may vary in taste and texture, but the original frosting is what typically defines the classic German Chocolate Cake.
# 32                                                                                                                                                                                                                                                                                                            \n\nSection: nutritional\nQuestion: What is the protein content?\nAnswer: The marbled cheesecake brownies has 7 grams of protein (PDV).
# 40                                                                                                                                                                                                                                                                                                                                                                       Carbohydrate levels of the fudge pudding cake you are ordering are 23 grams.
# 41                                                                                                                                                                                                                                                                                                                                                                                               The Spanish Lemon Cake typically has 485.7 calories.
# 46                                                                                                                                                                                           Based on the information provided, the chocolate chocolate pudding cake with chocolate ganache is not suitable if you are watching your weight. It has a high calorie status, high sugar content, 37 grams of carbohydrates, and 120 grams of total fat.
#
#           id  \
# 0   11252_10
# 4    31334_9
# 7    14457_8
# 9    18007_7
# 11  29935_10
# 13   16489_1
# 14   8847_14
# 18     916_5
# 21   19324_2
# 23   2923_14
# 24  12313_13
# 25   29801_5
# 27   9363_15
# 28   13178_4
# 31  10468_13
# 32   26912_6
# 40   13367_8
# 41  26017_15
# 46   9371_15
#
#                                                                                               question  \
# 0                                                              Are the cod cakes browned on both sides
# 4                                                               Milky Way Lover's Pound Cake prep time
# 7                                                   Does the rhubarb stir cake have a high carb count?
# 9                                           What's the fat content of the key lime cheesecake squares?
# 11                                             What's the instruction for baking the 1 Pan Fudge Cake?
# 13                                                Tell me the Million Dollar Pound Cake's composition?
# 14                                                                  Is carrot snack cake a sweet dish?
# 18                                                       Is the Momma's Fair Funnel Cake high in salt?
# 21                                   How many calories does the peach upside down pudding cake contain
# 23                                                      What flavor profile does 7 up pound cake have?
# 24                               What's the secret to achieving the Depression Fudge cake's rich color
# 25                          What's the sodium level in the flourless chocolate oh so good molten cake?
# 27                                             Would I gain weight eating Hand Me Down Chocolate Cake?
# 28                                    Can you tell me about the sugar content of the cheesecake kugel?
# 31         How does the original frosting compare to other frosting options for German Chocolate Cake?
# 32                   Can I have more information about the protein in the marbled cheesecake brownies?
# 40                                       What's the carb level of the fudge pudding cake I'm ordering?
# 41                                           How many calories does Spanish Lemon Cake typically have?
# 46  Can I order the Chocolate Chocolate Pudding Cake with Chocolate Ganache if I'm watching my weight?
#
#    relevance  \
# 0   RELEVANT
# 4   RELEVANT
# 7   RELEVANT
# 9   RELEVANT
# 11  RELEVANT
# 13  RELEVANT
# 14  RELEVANT
# 18  RELEVANT
# 21  RELEVANT
# 23  RELEVANT
# 24  RELEVANT
# 25  RELEVANT
# 27  RELEVANT
# 28  RELEVANT
# 31  RELEVANT
# 32  RELEVANT
# 40  RELEVANT
# 41  RELEVANT
# 46  RELEVANT
#
#                                                                                                                                                                                                                                                                                                                                                  explanation
# 0                                                                                                                                 The generated answer directly addresses the question by confirming that the cod cakes are browned on both sides after being fried in a skillet for 4-5 minutes. It provides a clear and relevant response to the question.
# 4                                                                                                                                                                       The generated answer directly addresses the question by providing the specific prep time of 30 minutes for Milky Way Lover's Pound Cake. It is fully relevant to the question asked.
# 7                                                                          The generated answer directly addresses the question by stating that the rhubarb stir cake does not have a high carb count. It also provides specific information about the amount of carbohydrates it contains (17 grams), which further supports its relevance to the question.
# 9                                                                                                              The generated answer directly addresses the fat content of the key lime cheesecake squares mentioned in the question, providing the specific amount of total fat (6 grams). This indicates a clear and accurate answer to the question asked.
# 11  The generated answer provides the step-by-step instructions for baking the 1 Pan Fudge Cake as requested in the question. It includes details such as preheating the oven, using an ungreased pan, sifting dry ingredients, adding liquids, baking time, and frosting the cake. The answer directly addresses the question and is relevant to the topic.
# 13                                                                                                                                                                                                                                      The answer directly provides the composition of the Million Dollar Pound Cake, listing all the ingredients included.
# 14                                                                                              The generated answer directly answers the question by confirming that carrot snack cake is indeed a sweet dish based on the high sugar content mentioned in the nutritional information provided. The answer is clear and directly relevant to the question.
# 18                                                                                        The generated answer directly addresses the question by stating that Momma's Fair Funnel Cake is not high in salt and provides a specific amount of sodium it contains. This information is relevant as it directly addresses the salt content of the funnel cake.
# 21                                                                                                                                   The generated answer directly addresses the question by providing the specific number of calories in the peach upside down pudding cake, which is 413.0 calories. This makes the answer relevant to the question asked.
# 23                                                                                                                                                                            The generated answer directly addresses the question by stating that the 7 up pound cake has a lemon-lime flavor profile, which is relevant to the flavor profile of the cake.
# 24                                                                                                                                    The generated answer directly addresses the question by identifying the cocoa as the secret to achieving the rich color of the Depression Fudge cake. It provides a clear and relevant response to the question asked.
# 25                                                                                                                            The generated answer directly addresses the sodium level in the flourless chocolate oh so good molten cake, providing the specific amount of sodium present in the cake. This makes the answer relevant to the question asked.
# 27                                                                                                 The generated answer directly addresses the question by providing information on the potential impact of eating Hand Me Down Chocolate Cake on weight gain. It mentions the cake's high fat and calorie content, which is relevant to the question asked.
# 28                                                                                                                                                   The answer directly provides the requested information about the sugar content of the cheesecake kugel, stating that it has 36 grams of sugar. Therefore, the answer is relevant to the question asked.
# 31                                                            The generated answer directly addresses the question by discussing how the original frosting for German Chocolate Cake compares to other frosting options. It provides information on the specific characteristics of the original frosting and how it is traditionally favored for this cake.
# 32                                                                                                           The generated answer directly addresses the question by providing the specific protein content of the marbled cheesecake brownies, which is what was asked for in the question. It is directly relevant and provides the information requested.
# 40                                                                                                                                                                                             The generated answer directly addresses the carb level of the fudge pudding cake being ordered, providing the specific information requested in the question.
# 41                                                                                                                                                         The generated answer directly addresses the question by providing the specific number of calories typically found in Spanish Lemon Cake. It is clear and directly relevant to the question asked.
# 46     The generated answer directly addresses the question by providing information about the calorie content, sugar content, and other nutritional information of the Chocolate Chocolate Pudding Cake with Chocolate Ganache. It clearly states that it is not suitable for someone watching their weight, making it a relevant response to the question.

# %% [markdown]
# ## Ingestion

# %%
# change path for base folder
base_folder = 'D:/Projects/AI-Restaurent-Chat-bot/'
input_data_folder = base_folder+'input_data/'

# %%
import pandas as pd
documents
# Out:
# [{'id': '142_1',
#   'question': 'What are the ingredients?',
#   'section': 'ingredients',
#   'text': "The almond fudge banana cake contains the following ingredients: ['dole banana', 'sugar', 'margarine', 'eggs', 'amaretto liqueur', 'vanilla extract', 'all-purpose flour', 'unsweetened cocoa powder', 'baking soda', 'salt', 'dole almond']",
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_2',
#   'question': 'How many calories does it have?',
#   'section': 'calories',
#   'text': 'The almond fudge banana cake has 224.8 calories.',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_3',
#   'question': 'How much total fat does it contain?',
#   'section': 'nutritional',
#   'text': 'The almond fudge banana cake has 14 grams of total fat (PDV).',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_4',
#   'question': 'What is the sugar content?',
#   'section': 'nutritional',
#   'text': 'The almond fudge banana cake has 87 grams of sugar (PDV).',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_5',
#   'question': 'How much sodium is in this dish?',
#   'section': 'nutritional',
#   'text': 'The almond fudge banana cake has 10 grams of sodium (PDV).',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_6',
#   'question': 'What is the protein content?',
#   'section': 'nutritional',
#   'text': 'The almond fudge banana cake has 7 grams of protein (PDV).',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_7',
#   'question': 'How much saturated fat is present?',
#   'section': 'nutritional',
#   'text': 'The almond fudge banana cake has 9 grams of saturated fat (PDV).',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_8',
#   'question': 'What are the carbohydrate levels?',
#   'section': 'nutritional',
#   'text': 'The almond fudge banana cake has 11 grams of carbohydrates (PDV).',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_9',
#   'question': 'How long does it take to prepare?',
#   'section': 'preparation',
#   'text': 'The almond fudge banana cake takes 110 minutes to prepare.',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_10',
#   'question': 'What are the steps to prepare this dish?',
#   'section': 'steps',
#   'text': "The almond fudge banana cake contains ['mash bananas and set aside', 'beat sugar and margarine until light and fluffy', 'beat in eggs , liqueur and vanilla', 'combine dry ingredients', 'stir in almonds', 'add to sugar mixture alternately with bananas', 'beat well', 'pour batter into greased 10-inch bundt pan', 'bake in preheated 350f oven 45 to 50 minutes or until toothpick inserted in center comes out almost clean and cake pulls away from side of pan', 'cool 10 minutes', 'remove cake from pan to wire rack to cool completely', 'drizzle glaze over top and down side of cake', 'make 16-20 servings']",
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_11',
#   'question': 'What tags are associated with this dish?',
#   'section': 'tags',
#   'text': "The almond fudge banana cake contains ['weeknight', 'time-to-make', 'course', 'preparation', 'for-large-groups', 'desserts', 'oven', 'cakes', 'dietary', 'equipment', 'number-of-servings', '4-hours-or-less']",
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_12',
#   'question': 'What is the rating of this dish?',
#   'section': 'rating',
#   'text': 'The almond fudge banana cake has a rating of 4.',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_13',
#   'question': 'Can you provide a review?',
#   'section': 'review',
#   'text': 'Review for almond fudge banana cake: Came out great for a chocolate Easter cake. I made an almond cream cheese frosting instead of a chocolate glaze to make it more Spring-like. Very moist and the banana is definately the strongest flavor coming from the cake. Will definately make again.',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_14',
#   'question': 'What category does this dish fall under?',
#   'section': 'category',
#   'text': 'The category of almond fudge banana cake is tasty.',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_15',
#   'question': 'What is the calorie status of this dish?',
#   'section': 'calorie_status',
#   'text': 'The calorie status of almond fudge banana cake is Low Calory.',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '142_16',
#   'question': 'What is the price of this dish?',
#   'section': 'price',
#   'text': 'The price of almond fudge banana cake is $24.',
#   'dish_name': 'almond fudge banana cake'},
#  {'id': '520_1',
#   'question': 'What are the ingredients?',
#   'section': 'ingredients',
#   'text': "The apple pie cake contains the following ingredients: ['sugar', 'egg', 'salt', 'butter', 'flour', 'baking powder', 'cinnamon', 'nutmeg', 'vanilla', 'baking apples', 'pecans', 'golden raisin']",
#   'dish_name': 'apple pie cake'},
#  {'id': '520_2',
#   'question': 'How many calories does it have?',
#   'section': 'calories',
#   'text': 'The apple pie cake has 359.1 calories.',
#   'dish_name': 'apple pie cake'},
#  {'id': '520_3',
#   'question': 'How much total fat does it contain?',
#   'section': 'nutritional',
#   'text': 'The apple pie cake has 26 grams of total fat (PDV).',
#   'dish_name': 'apple pie cake'},
#  {'id': '520_4',
#   'question': 'What is the sugar content?',
#   'section': 'nutritional',
#   'text': 'The apple pie cake has 136 grams of sugar (PDV).',
#   'dish_name': 'apple pie cake'},
#  {'id': '520_5',
#   'question': 'How much sodium is in this dish?',
#   'section': 'nutritional',
#   'text': 'The apple pie cake has 18 grams of sodium (PDV).',
#   'dish_name': 'apple pie cake'},
#  {'id': '520_6',
#   'question': 'What is the protein content?',
#   'section': 'nutritional',
#   'text': 'The apple pie cake has 7 grams of protein (PDV).',
#   'dish_name': 'apple pie cake'},
#  {'id': '520_7',
#   'question': 'How much saturated fat is present?',
#   'section': 'nutritional',
#   'text': 'The apple pie cake has 40 grams of saturated fat (PDV).',
#   'dish_name': 'apple pie cake'},
#  {'id': '520_8',
#   'question': 'What are the carbohydrate levels?',
#   'section': 'nutritional',
#   'text': 'The apple pie cake has 16 grams of carbohydrates (PDV).',
#   'dish_name': 'apple pie cake'},
#  {'id': '520_9',
#   'question': 'How long does it take to prepare?',
#   'section': 'preparation',
#   'text': 'The apple pie cake takes 40 minutes to prepare.',
#   'dish_name': 'apple pie cake'},
#  {'id': '520_10',
#   'question': 'What are the steps to prepare this dish?',
#   'section': 'steps',
#   'text': "The apple pie cake contains ['cream butter , sugar and the egg', 'mix together the flour , baking powder , cinnamon , salt , nutmeg , vanilla , apples , pecans , and raisins', 'mix together well with the creamed mixture', 'pour the batter into a round pie dish and bake at 350 30 to 40 minutes or until the cake is done and a toothpick inserted near the center comes out clean , not doughy']",
#   'dish_name': 'apple pie cake'},
#  {'id': '520_11',
#   'question': 'What tags are associated with this dish?',
#   'section': 'tags',
#   'text': "The apple pie cake contains ['60-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'cuisine', 'preparation', 'north-american', 'pies-and-tarts', 'desserts', 'fruit', 'american', 'oven', 'cakes', 'pies', 'dietary', 'apples', 'equipment', 'number-of-servings']",
#   'dish_name': 'apple pie cake'},
#  {'id': '520_12',
#   'question': 'What is the rating of this dish?',
#   'section': 'rating',
#   'text': 'The apple pie cake has a rating of 3.',
#   'dish_name': 'apple pie cake'},
#  {'id': '520_13',
#   'question': 'Can you provide a review?',
#   'section': 'review',
#   'text': "Review for apple pie cake: The flavor of this was good, but the making of it didn't go very well.  There were a lot of steps, which isn't necessarily a  bad thing, but it didn't fall together like most cake recipes.  For example, I couldn't figure out why I had to melt the butter (and of course cool it) when I was just creaming it, or why add the sugar in two parts.   I had tons of tunnels.  And it would be helpful if there was a number for how long to bake.  At least a range, especially for us novice cooks.   It took 45 minutes for me.",
#   'dish_name': 'apple pie cake'},
#  {'id': '520_14',
#   'question': 'What category does this dish fall under?',
#   'section': 'category',
#   'text': 'The category of apple pie cake is so so.',
#   'dish_name': 'apple pie cake'},
#  {'id': '520_15',
#   'question': 'What is the calorie status of this dish?',
#   'section': 'calorie_status',
#   'text': 'The calorie status of apple pie cake is Low Calory.',
#   'dish_name': 'apple pie cake'},
#  {'id': '520_16',
#   'question': 'What is the price of this dish?',
#   'section': 'price',
#   'text': 'The price of apple pie cake is $20.',
#   'dish_name': 'apple pie cake'},
#  {'id': '822_1',
#   'question': 'What are the ingredients?',
#   'section': 'ingredients',
#   'text': "The heloise s cake mix cookies contains the following ingredients: ['cake mix', 'vegetable oil', 'eggs']",
#   'dish_name': 'heloise s cake mix cookies'},
#  {'id': '822_2',
#   'question': 'How many calories does it have?',
#   'section': 'calories',
#   'text': 'The heloise s cake mix cookies has 137.4 calories.',
#   'dish_name': 'heloise s cake mix cookies'},
#  {'id': '822_3',
#   'question': 'How much total fat does it contain?',
#   'section': 'nutritional',
#   'text': 'The heloise s cake mix cookies has 11 grams of total fat (PDV).',
#   'dish_name': 'heloise s cake mix cookies'},
#  {'id': '822_4',
#   'question': 'What is the sugar content?',
#   'section': 'nutritional',
#   'text': 'The heloise s cake mix cookies has 46 grams of sugar (PDV).',
#   'dish_name': 'heloise s cake mix cookies'},
#  {'id': '822_5',
#   'question': 'How much sodium is in this dish?',
#   'section': 'nutritional',
#   'text': 'The heloise s cake mix cookies has 6 grams of sodium (PDV).',
#   'dish_name': 'heloise s cake mix cookies'},
#  {'id': '822_6',
#   'question': 'What is the protein content?',
#   'section': 'nutritional',
#   'text': 'The heloise s cake mix cookies has 2 grams of protein (PDV).',
#   'dish_name': 'heloise s cake mix cookies'},
#  {'id': '822_7',
#   'question': 'How much saturated fat is present?',
#   'section': 'nutritional',
#   'text': 'The heloise s cake mix cookies has 5 grams of saturated fat (PDV).',
#   'dish_name': 'heloise s cake mix cookies'},
#  {'id': '822_8',
#   'question': 'What are the carbohydrate levels?',
#   'section': 'nutritional',
#   'text': 'The heloise s cake mix cookies has 5 grams of carbohydrates (PDV).',
#   'dish_name': 'heloise s cake mix cookies'},
#  {'id': '822_9',
#   'question': 'How long does it take to prepare?',
#   'section': 'preparation',
#   'text': 'The heloise s cake mix cookies takes 8 minutes to prepare.',
#   'dish_name': 'heloise s cake mix cookies'},
#  {'id': '822_10',
#   'question': 'What are the steps to prepare this dish?',
#   'section': 'steps',
#   'text': "The heloise s cake mix cookies contains ['mix all ingredients well to remove lumps', 'stir in raisins and / or nuts and / or chocolate chips if you so desire', 'drop by teaspoonfuls on an ungreased baking sheet about 2-inches apart', 'bake at 350f for 8-10 minutes']",
#   'dish_name': 'heloise s cake mix cookies'},
#  {'id': '822_11',
#   'question': 'What tags are associated with this dish?',
#   'section': 'tags',
#   'text': "The heloise s cake mix cookies contains ['15-minutes-or-less', 'time-to-make', 'course', 'preparation', '5-ingredients-or-less', 'drop-cookies', 'desserts', 'oven', 'easy', 'cakes', 'cookies-and-brownies', 'dietary', 'equipment', 'number-of-servings']",
#   'dish_name': 'heloise s cake mix cookies'},
#  {'id': '822_12',
#   'question': 'What is the rating of this dish?',
#   'section': 'rating',
#   'text': 'The heloise s cake mix cookies has a rating of 5.',
#   'dish_name': 'heloise s cake mix cookies'},
#  {'id': '822_13',
#   'question': 'Can you provide a review?',
#   'section': 'review',
#   'text': 'Review for heloise s cake mix cookies: What a great recipe!  Inexpensive and EASY!!  My favorite is a chocolate cake with peanut butter chips.  Yum!',
#   'dish_name': 'heloise s cake mix cookies'},
#  {'id': '822_14',
#   'question': 'What category does this dish fall under?',
#   'section': 'category',
#   'text': 'The category of heloise s cake mix cookies is tasty.',
#   'dish_name': 'heloise s cake mix cookies'},
#  {'id': '822_15',
#   'question': 'What is the calorie status of this dish?',
#   'section': 'calorie_status',
#   'text': 'The calorie status of heloise s cake mix cookies is Low Calory.',
#   'dish_name': 'heloise s cake mix cookies'},
#  {'id': '822_16',
#   'question': 'What is the price of this dish?',
#   'section': 'price',
#   'text': 'The price of heloise s cake mix cookies is $44.',
#   'dish_name': 'heloise s cake mix cookies'},
#  {'id': '916_1',
#   'question': 'What are the ingredients?',
#   'section': 'ingredients',
#   'text': "The momma s fair funnel cake contains the following ingredients: ['eggs', 'sugar', 'milk', 'flour', 'salt', 'baking powder', 'vegetable oil']",
#   'dish_name': 'momma s fair funnel cake'},
#  {'id': '916_2',
#   'question': 'How many calories does it have?',
#   'section': 'calories',
#   'text': 'The momma s fair funnel cake has 398.9 calories.',
#   'dish_name': 'momma s fair funnel cake'},
#  {'id': '916_3',
#   'question': 'How much total fat does it contain?',
#   'section': 'nutritional',
#   'text': 'The momma s fair funnel cake has 9 grams of total fat (PDV).',
#   'dish_name': 'momma s fair funnel cake'},
#  {'id': '916_4',
#   'question': 'What is the sugar content?',
#   'section': 'nutritional',
#   'text': 'The momma s fair funnel cake has 34 grams of sugar (PDV).',
#   'dish_name': 'momma s fair funnel cake'},
#  {'id': '916_5',
#   'question': 'How much sodium is in this dish?',
#   'section': 'nutritional',
#   'text': 'The momma s fair funnel cake has 16 grams of sodium (PDV).',
#   'dish_name': 'momma s fair funnel cake'},
#  {'id': '916_6',
#   'question': 'What is the protein content?',
#   'section': 'nutritional',
#   'text': 'The momma s fair funnel cake has 27 grams of protein (PDV).',
#   'dish_name': 'momma s fair funnel cake'},
#  {'id': '916_7',
#   'question': 'How much saturated fat is present?',
#   'section': 'nutritional',
#   'text': 'The momma s fair funnel cake has 13 grams of saturated fat (PDV).',
#   'dish_name': 'momma s fair funnel cake'},
#  {'id': '916_8',
#   'question': 'What are the carbohydrate levels?',
#   'section': 'nutritional',
#   'text': 'The momma s fair funnel cake has 23 grams of carbohydrates (PDV).',
#   'dish_name': 'momma s fair funnel cake'},
#  {'id': '916_9',
#   'question': 'How long does it take to prepare?',
#   'section': 'preparation',
#   'text': 'The momma s fair funnel cake takes 20 minutes to prepare.',
#   'dish_name': 'momma s fair funnel cake'},
#  {'id': '916_10',
#   'question': 'What are the steps to prepare this dish?',
#   'section': 'steps',
#   'text': "The momma s fair funnel cake contains ['beat eggs and sugar together and then add the milk slowly--beat', 'add the dry ingredients and beat until smooth and creamy', 'pour batter into a funnel and at the same time , use your finger to plug the hole', 'in a large cast iron pot , add 2 inches of oil to the bottom', 'when the oil becomes hot , move your hand over the pot and slowly release your finger so the batter can start cooking', 'move the funnel around to make designs', 'brown on both sides--then immediately remove and drain extremely well', 'top with brown sugar , or honey , or cinnamon sugar , or powdered sugar as a topping', 'be careful and do not get burned !']",
#   'dish_name': 'momma s fair funnel cake'},
#  {'id': '916_11',
#   'question': 'What tags are associated with this dish?',
#   'section': 'tags',
#   'text': "The momma s fair funnel cake contains ['30-minutes-or-less', 'time-to-make', 'course', 'preparation', 'healthy', 'desserts', 'cakes', 'dietary', 'number-of-servings']",
#   'dish_name': 'momma s fair funnel cake'},
#  {'id': '916_12',
#   'question': 'What is the rating of this dish?',
#   'section': 'rating',
#   'text': 'The momma s fair funnel cake has a rating of 5.',
#   'dish_name': 'momma s fair funnel cake'},
#  {'id': '916_13',
#   'question': 'Can you provide a review?',
#   'section': 'review',
#   'text': 'Review for momma s fair funnel cake: This is a great recipe, its small, quick and tastes great.',
#   'dish_name': 'momma s fair funnel cake'},
#  {'id': '916_14',
#   'question': 'What category does this dish fall under?',
#   'section': 'category',
#   'text': 'The category of momma s fair funnel cake is tasty.',
#   'dish_name': 'momma s fair funnel cake'},
#  {'id': '916_15',
#   'question': 'What is the calorie status of this dish?',
#   'section': 'calorie_status',
#   'text': 'The calorie status of momma s fair funnel cake is Low Calory.',
#   'dish_name': 'momma s fair funnel cake'},
#  {'id': '916_16',
#   'question': 'What is the price of this dish?',
#   'section': 'price',
#   'text': 'The price of momma s fair funnel cake is $31.',
#   'dish_name': 'momma s fair funnel cake'},
#  {'id': '1633_1',
#   'question': 'What are the ingredients?',
#   'section': 'ingredients',
#   'text': "The mc donald s pancakes contains the following ingredients: ['carbonated lemon-lime beverage', 'egg', 'sugar', 'oil', 'biscuit mix']",
#   'dish_name': 'mc donald s pancakes'},
#  {'id': '1633_2',
#   'question': 'How many calories does it have?',
#   'section': 'calories',
#   'text': 'The mc donald s pancakes has 225.6 calories.',
#   'dish_name': 'mc donald s pancakes'},
#  {'id': '1633_3',
#   'question': 'How much total fat does it contain?',
#   'section': 'nutritional',
#   'text': 'The mc donald s pancakes has 14 grams of total fat (PDV).',
#   'dish_name': 'mc donald s pancakes'},
#  {'id': '1633_4',
#   'question': 'What is the sugar content?',
#   'section': 'nutritional',
#   'text': 'The mc donald s pancakes has 39 grams of sugar (PDV).',
#   'dish_name': 'mc donald s pancakes'},
#  {'id': '1633_5',
#   'question': 'How much sodium is in this dish?',
#   'section': 'nutritional',
#   'text': 'The mc donald s pancakes has 16 grams of sodium (PDV).',
#   'dish_name': 'mc donald s pancakes'},
#  {'id': '1633_6',
#   'question': 'What is the protein content?',
#   'section': 'nutritional',
#   'text': 'The mc donald s pancakes has 8 grams of protein (PDV).',
#   'dish_name': 'mc donald s pancakes'},
#  {'id': '1633_7',
#   'question': 'How much saturated fat is present?',
#   'section': 'nutritional',
#   'text': 'The mc donald s pancakes has 10 grams of saturated fat (PDV).',
#   'dish_name': 'mc donald s pancakes'},
#  {'id': '1633_8',
#   'question': 'What are the carbohydrate levels?',
#   'section': 'nutritional',
#   'text': 'The mc donald s pancakes has 10 grams of carbohydrates (PDV).',
#   'dish_name': 'mc donald s pancakes'},
#  {'id': '1633_9',
#   'question': 'How long does it take to prepare?',
#   'section': 'preparation',
#   'text': 'The mc donald s pancakes takes 20 minutes to prepare.',
#   'dish_name': 'mc donald s pancakes'},
#  {'id': '1633_10',
#   'question': 'What are the steps to prepare this dish?',
#   'section': 'steps',
#   'text': "The mc donald s pancakes contains ['put all ingredients into a blender', 'blend on high speed a few seconds until smooth', 'let stand 10 minutes before using 1 / 4 cup batter for each pancake on hot , oiled griddle , browning each side', 'makes 8 to 10 pancakes']",
#   'dish_name': 'mc donald s pancakes'},
#  {'id': '1633_11',
#   'question': 'What tags are associated with this dish?',
#   'section': 'tags',
#   'text': "The mc donald s pancakes contains ['30-minutes-or-less', 'time-to-make', 'course', 'preparation', '5-ingredients-or-less', 'pancakes-and-waffles', 'breakfast', 'easy', 'dietary', '3-steps-or-less']",
#   'dish_name': 'mc donald s pancakes'},
#  {'id': '1633_12',
#   'question': 'What is the rating of this dish?',
#   'section': 'rating',
#   'text': 'The mc donald s pancakes has a rating of 5.',
#   'dish_name': 'mc donald s pancakes'},
#  {'id': '1633_13',
#   'question': 'Can you provide a review?',
#   'section': 'review',
#   'text': 'Review for mc donald s pancakes: OMG, these are great! I was looking for something faster than scratch, but more interesting than plain baking mix. This fit the bill, perfectly. I did have to add about 1/2 C. of milk to thin, as the batter was too thick to scoop. But with that only addition, they were super! Very high-rising and light and fluffy. DH gave them 5 stars. They were delicious with Louisiana cane syrup. Thanks so much for sharing, CeeDee! ',
#   'dish_name': 'mc donald s pancakes'},
#  {'id': '1633_14',
#   'question': 'What category does this dish fall under?',
#   'section': 'category',
#   'text': 'The category of mc donald s pancakes is tasty.',
#   'dish_name': 'mc donald s pancakes'},
#  {'id': '1633_15',
#   'question': 'What is the calorie status of this dish?',
#   'section': 'calorie_status',
#   'text': 'The calorie status of mc donald s pancakes is Low Calory.',
#   'dish_name': 'mc donald s pancakes'},
#  {'id': '1633_16',
#   'question': 'What is the price of this dish?',
#   'section': 'price',
#   'text': 'The price of mc donald s pancakes is $31.',
#   'dish_name': 'mc donald s pancakes'},
#  {'id': '2496_1',
#   'question': 'What are the ingredients?',
#   'section': 'ingredients',
#   'text': "The dark chocolate cake contains the following ingredients: ['sugar', 'flour', 'baking cocoa', 'baking powder', 'baking soda', 'salt', 'eggs', 'milk', 'vegetable oil', 'vanilla extract', 'boiling water']",
#   'dish_name': 'dark chocolate cake'},
#  {'id': '2496_2',
#   'question': 'How many calories does it have?',
#   'section': 'calories',
#   'text': 'The dark chocolate cake has 189.1 calories.',
#   'dish_name': 'dark chocolate cake'},
#  {'id': '2496_3',
#   'question': 'How much total fat does it contain?',
#   'section': 'nutritional',
#   'text': 'The dark chocolate cake has 10 grams of total fat (PDV).',
#   'dish_name': 'dark chocolate cake'},
#  {'id': '2496_4',
#   'question': 'What is the sugar content?',
#   'section': 'nutritional',
#   'text': 'The dark chocolate cake has 80 grams of sugar (PDV).',
#   'dish_name': 'dark chocolate cake'},
#  {'id': '2496_5',
#   'question': 'How much sodium is in this dish?',
#   'section': 'nutritional',
#   'text': 'The dark chocolate cake has 10 grams of sodium (PDV).',
#   'dish_name': 'dark chocolate cake'},
#  {'id': '2496_6',
#   'question': 'What is the protein content?',
#   'section': 'nutritional',
#   'text': 'The dark chocolate cake has 5 grams of protein (PDV).',
#   'dish_name': 'dark chocolate cake'},
#  {'id': '2496_7',
#   'question': 'How much saturated fat is present?',
#   'section': 'nutritional',
#   'text': 'The dark chocolate cake has 7 grams of saturated fat (PDV).',
#   'dish_name': 'dark chocolate cake'},
#  {'id': '2496_8',
#   'question': 'What are the carbohydrate levels?',
#   'section': 'nutritional',
#   'text': 'The dark chocolate cake has 10 grams of carbohydrates (PDV).',
#   'dish_name': 'dark chocolate cake'},
#  {'id': '2496_9',
#   'question': 'How long does it take to prepare?',
#   'section': 'preparation',
#   'text': 'The dark chocolate cake takes 60 minutes to prepare.',
#   'dish_name': 'dark chocolate cake'},
#  {'id': '2496_10',
#   'question': 'What are the steps to prepare this dish?',
#   'section': 'steps',
#   'text': 'The dark chocolate cake contains [\'heat oven to 350f\', \'grease and flour two 9 inch round baking pans or one 13x9 inch pan\', \'in large mixer bowl , stir together dry ingredients\', \'add eggs , milk , oil , and vanilla\', \'beat on medium speed for 2 minutes\', \'stir in boiling water by hand\', \'i usually use between 2 / 3 & 3 / 4 cups\', \'the cake is still very moist but it doesn\\\'t seem to "fall" as much as it cools\', "this might have to do with our high humidity or brand of flour or other factors so i don\'t know if it will work for everyone", \'pour into prepared pan\', \'bake 30 to 35 minutes for round 9-inch pans , 35 to 40 minutes for rectangular pan or until wooden pick inserted in center comes out clean\', \'because they have a tendency to overflow if you fill them more than 2 / 3 full , i usually get about 27-28 cupcakes per batch\', \'bake for approximately 18-20 minutes\', \'cool 10 minutes\', \'remove from pan to wire racks\', \'please\', \'chocolate drink mixes that you add to milk or water to drink will not work in this recipe\']',
#   'dish_name': 'dark chocolate cake'},
#  {'id': '2496_11',
#   'question': 'What tags are associated with this dish?',
#   'section': 'tags',
#   'text': "The dark chocolate cake contains ['60-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'preparation', 'for-large-groups', 'desserts', 'oven', 'cakes', 'chocolate', 'dietary', 'equipment', 'number-of-servings']",
#   'dish_name': 'dark chocolate cake'},
#  {'id': '2496_12',
#   'question': 'What is the rating of this dish?',
#   'section': 'rating',
#   'text': 'The dark chocolate cake has a rating of 5.',
#   'dish_name': 'dark chocolate cake'},
#  {'id': '2496_13',
#   'question': 'Can you provide a review?',
#   'section': 'review',
#   'text': "Review for dark chocolate cake: Well, it wasn't really a dark chocolate cake to me, but I've been rather spoiled by my grandma's cake recipe, so I'm not a very good judge. However, it was surprisingly moist and rich for such a simple cake. I used a chocolate frosting and put fresh raspberries between the layers and on top for my little sister's birthday. It was great! Thanks for the recipe. ",
#   'dish_name': 'dark chocolate cake'},
#  {'id': '2496_14',
#   'question': 'What category does this dish fall under?',
#   'section': 'category',
#   'text': 'The category of dark chocolate cake is tasty.',
#   'dish_name': 'dark chocolate cake'},
#  {'id': '2496_15',
#   'question': 'What is the calorie status of this dish?',
#   'section': 'calorie_status',
#   'text': 'The calorie status of dark chocolate cake is Low Calory.',
#   'dish_name': 'dark chocolate cake'},
#  {'id': '2496_16',
#   'question': 'What is the price of this dish?',
#   'section': 'price',
#   'text': 'The price of dark chocolate cake is $37.',
#   'dish_name': 'dark chocolate cake'},
#  {'id': '2695_1',
#   'question': 'What are the ingredients?',
#   'section': 'ingredients',
#   'text': "The lemon jello cake contains the following ingredients: ['yellow cake mix', 'lemon jell-o gelatin', 'eggs', 'water', 'vegetable oil', 'powdered sugar', 'lemons, juice and zest of', 'butter']",
#   'dish_name': 'lemon jello cake'},
#  {'id': '2695_2',
#   'question': 'How many calories does it have?',
#   'section': 'calories',
#   'text': 'The lemon jello cake has 456.9 calories.',
#   'dish_name': 'lemon jello cake'},
#  {'id': '2695_3',
#   'question': 'How much total fat does it contain?',
#   'section': 'nutritional',
#   'text': 'The lemon jello cake has 34 grams of total fat (PDV).',
#   'dish_name': 'lemon jello cake'},
#  {'id': '2695_4',
#   'question': 'What is the sugar content?',
#   'section': 'nutritional',
#   'text': 'The lemon jello cake has 179 grams of sugar (PDV).',
#   'dish_name': 'lemon jello cake'},
#  {'id': '2695_5',
#   'question': 'How much sodium is in this dish?',
#   'section': 'nutritional',
#   'text': 'The lemon jello cake has 15 grams of sodium (PDV).',
#   'dish_name': 'lemon jello cake'},
#  {'id': '2695_6',
#   'question': 'What is the protein content?',
#   'section': 'nutritional',
#   'text': 'The lemon jello cake has 9 grams of protein (PDV).',
#   'dish_name': 'lemon jello cake'},
#  {'id': '2695_7',
#   'question': 'How much saturated fat is present?',
#   'section': 'nutritional',
#   'text': 'The lemon jello cake has 21 grams of saturated fat (PDV).',
#   'dish_name': 'lemon jello cake'},
#  {'id': '2695_8',
#   'question': 'What are the carbohydrate levels?',
#   'section': 'nutritional',
#   'text': 'The lemon jello cake has 20 grams of carbohydrates (PDV).',
#   'dish_name': 'lemon jello cake'},
#  {'id': '2695_9',
#   'question': 'How long does it take to prepare?',
#   'section': 'preparation',
#   'text': 'The lemon jello cake takes 45 minutes to prepare.',
#   'dish_name': 'lemon jello cake'},
#  {'id': '2695_10',
#   'question': 'What are the steps to prepare this dish?',
#   'section': 'steps',
#   'text': "The lemon jello cake contains ['mix cake ingredients together for 4 minutes', 'bake in metal non stick 9x13 inch pan @350 for 40 minutes', 'or , if using a glass baking dish bake @325 for 45 minutes', 'poke holes all over the cake while hot', 'mix together icing: powdered sugar and lemons', 'pour this over the cake immediately , while it is still hot from the oven', 'serve warm or cold']",
#   'dish_name': 'lemon jello cake'},
#  {'id': '2695_11',
#   'question': 'What tags are associated with this dish?',
#   'section': 'tags',
#   'text': "The lemon jello cake contains ['60-minutes-or-less', 'time-to-make', 'course', 'preparation', 'occasion', 'gelatin', 'desserts', 'oven', 'cakes', 'dietary', 'equipment', 'number-of-servings']",
#   'dish_name': 'lemon jello cake'},
#  {'id': '2695_12',
#   'question': 'What is the rating of this dish?',
#   'section': 'rating',
#   'text': 'The lemon jello cake has a rating of 0.',
#   'dish_name': 'lemon jello cake'},
#  {'id': '2695_13',
#   'question': 'Can you provide a review?',
#   'section': 'review',
#   'text': "Review for lemon jello cake: There were two recipes that I received in the late fifties or 60's.  They were so great then.  The other recipe was Orange Jello Cake, using Orange Jello with White Cake Mix.  They were fast, simple, moist, and rated excellent then.\nMy recipes are packed for moving; so I cannot give you the baking temperature or time.",
#   'dish_name': 'lemon jello cake'},
#  {'id': '2695_14',
#   'question': 'What category does this dish fall under?',
#   'section': 'category',
#   'text': 'The category of lemon jello cake is bad.',
#   'dish_name': 'lemon jello cake'},
#  {'id': '2695_15',
#   'question': 'What is the calorie status of this dish?',
#   'section': 'calorie_status',
#   'text': 'The calorie status of lemon jello cake is Low Calory.',
#   'dish_name': 'lemon jello cake'},
#  {'id': '2695_16',
#   'question': 'What is the price of this dish?',
#   'section': 'price',
#   'text': 'The price of lemon jello cake is $46.',
#   'dish_name': 'lemon jello cake'},
#  {'id': '2767_1',
#   'question': 'What are the ingredients?',
#   'section': 'ingredients',
#   'text': "The moms chocolate zucchini cake contains the following ingredients: ['margarine', 'oil', 'sugar', 'eggs', 'vanilla', 'sour milk', 'flour', 'baking cocoa', 'baking powder', 'baking soda', 'cinnamon', 'zucchini', 'chocolate chips']",
#   'dish_name': 'moms chocolate zucchini cake'},
#  {'id': '2767_2',
#   'question': 'How many calories does it have?',
#   'section': 'calories',
#   'text': 'The moms chocolate zucchini cake has 138.8 calories.',
#   'dish_name': 'moms chocolate zucchini cake'},
#  {'id': '2767_3',
#   'question': 'How much total fat does it contain?',
#   'section': 'nutritional',
#   'text': 'The moms chocolate zucchini cake has 10 grams of total fat (PDV).',
#   'dish_name': 'moms chocolate zucchini cake'},
#  {'id': '2767_4',
#   'question': 'What is the sugar content?',
#   'section': 'nutritional',
#   'text': 'The moms chocolate zucchini cake has 45 grams of sugar (PDV).',
#   'dish_name': 'moms chocolate zucchini cake'},
#  {'id': '2767_5',
#   'question': 'How much sodium is in this dish?',
#   'section': 'nutritional',
#   'text': 'The moms chocolate zucchini cake has 3 grams of sodium (PDV).',
#   'dish_name': 'moms chocolate zucchini cake'},
#  {'id': '2767_6',
#   'question': 'What is the protein content?',
#   'section': 'nutritional',
#   'text': 'The moms chocolate zucchini cake has 3 grams of protein (PDV).',
#   'dish_name': 'moms chocolate zucchini cake'},
#  {'id': '2767_7',
#   'question': 'How much saturated fat is present?',
#   'section': 'nutritional',
#   'text': 'The moms chocolate zucchini cake has 7 grams of saturated fat (PDV).',
#   'dish_name': 'moms chocolate zucchini cake'},
#  {'id': '2767_8',
#   'question': 'What are the carbohydrate levels?',
#   'section': 'nutritional',
#   'text': 'The moms chocolate zucchini cake has 6 grams of carbohydrates (PDV).',
#   'dish_name': 'moms chocolate zucchini cake'},
#  {'id': '2767_9',
#   'question': 'How long does it take to prepare?',
#   'section': 'preparation',
#   'text': 'The moms chocolate zucchini cake takes 90 minutes to prepare.',
#   'dish_name': 'moms chocolate zucchini cake'},
#  {'id': '2767_10',
#   'question': 'What are the steps to prepare this dish?',
#   'section': 'steps',
#   'text': "The moms chocolate zucchini cake contains ['there are many versions of this recipe , this one we like the best for our family ! beat margarine , oil and sugar well', 'beat in eggs , vanilla and sour milk', 'sift dry ingredients and beat into mixture', 'stir in zucchini', 'pour batter into a greased and floured tube or bundt pan', 'sprinkle top of batter with chips bake in a 325f oven 40 to 45 minutes or tested done', 'cool in pan 15 minutes and carefully remove to finish cooling', 'sprinkle with powder sugar if desired', 'freezes well and tastes wonderful !']",
#   'dish_name': 'moms chocolate zucchini cake'},
#  {'id': '2767_11',
#   'question': 'What tags are associated with this dish?',
#   'section': 'tags',
#   'text': "The moms chocolate zucchini cake contains ['time-to-make', 'course', 'main-ingredient', 'preparation', 'occasion', 'desserts', 'oven', 'cakes', 'chocolate', 'dietary', 'equipment', 'number-of-servings', '4-hours-or-less']",
#   'dish_name': 'moms chocolate zucchini cake'},
#  {'id': '2767_12',
#   'question': 'What is the rating of this dish?',
#   'section': 'rating',
#   'text': 'The moms chocolate zucchini cake has a rating of 0.',
#   'dish_name': 'moms chocolate zucchini cake'},
#  {'id': '2767_13',
#   'question': 'Can you provide a review?',
#   'section': 'review',
#   'text': 'Review for moms chocolate zucchini cake: I made this recipe and just wanted to say that the cake really needs to cook much longer! I had it in for about 60-65 minutes!',
#   'dish_name': 'moms chocolate zucchini cake'},
#  {'id': '2767_14',
#   'question': 'What category does this dish fall under?',
#   'section': 'category',
#   'text': 'The category of moms chocolate zucchini cake is bad.',
#   'dish_name': 'moms chocolate zucchini cake'},
#  {'id': '2767_15',
#   'question': 'What is the calorie status of this dish?',
#   'section': 'calorie_status',
#   'text': 'The calorie status of moms chocolate zucchini cake is Low Calory.',
#   'dish_name': 'moms chocolate zucchini cake'},
#  {'id': '2767_16',
#   'question': 'What is the price of this dish?',
#   'section': 'price',
#   'text': 'The price of moms chocolate zucchini cake is $37.',
#   'dish_name': 'moms chocolate zucchini cake'},
#  {'id': '2923_1',
#   'question': 'What are the ingredients?',
#   'section': 'ingredients',
#   'text': "The 7 up pound cake contains the following ingredients: ['butter', 'sugar', 'eggs', 'cake flour', 'lemon flavoring', 'carbonated lemon-lime beverage']",
#   'dish_name': '7 up pound cake'},
#  {'id': '2923_2',
#   'question': 'How many calories does it have?',
#   'section': 'calories',
#   'text': 'The 7 up pound cake has 556.9 calories.',
#   'dish_name': '7 up pound cake'},
#  {'id': '2923_3',
#   'question': 'How much total fat does it contain?',
#   'section': 'nutritional',
#   'text': 'The 7 up pound cake has 38 grams of total fat (PDV).',
#   'dish_name': '7 up pound cake'},
#  {'id': '2923_4',
#   'question': 'What is the sugar content?',
#   'section': 'nutritional',
#   'text': 'The 7 up pound cake has 205 grams of sugar (PDV).',
#   'dish_name': '7 up pound cake'},
#  {'id': '2923_5',
#   'question': 'How much sodium is in this dish?',
#   'section': 'nutritional',
#   'text': 'The 7 up pound cake has 9 grams of sodium (PDV).',
#   'dish_name': '7 up pound cake'},
#  {'id': '2923_6',
#   'question': 'What is the protein content?',
#   'section': 'nutritional',
#   'text': 'The 7 up pound cake has 11 grams of protein (PDV).',
#   'dish_name': '7 up pound cake'},
#  {'id': '2923_7',
#   'question': 'How much saturated fat is present?',
#   'section': 'nutritional',
#   'text': 'The 7 up pound cake has 76 grams of saturated fat (PDV).',
#   'dish_name': '7 up pound cake'},
#  {'id': '2923_8',
#   'question': 'What are the carbohydrate levels?',
#   'section': 'nutritional',
#   'text': 'The 7 up pound cake has 26 grams of carbohydrates (PDV).',
#   'dish_name': '7 up pound cake'},
#  {'id': '2923_9',
#   'question': 'How long does it take to prepare?',
#   'section': 'preparation',
#   'text': 'The 7 up pound cake takes 75 minutes to prepare.',
#   'dish_name': '7 up pound cake'},
#  {'id': '2923_10',
#   'question': 'What are the steps to prepare this dish?',
#   'section': 'steps',
#   'text': "The 7 up pound cake contains ['preheat oven to 300f and grease / flour a tube pan', 'cream butter and sugar together until light and fluffy', 'add eggs one at a time , beating after each one', 'add flour alternating with 7-up', 'stir in lemon flavoring', 'bake in prepared pan until cake tests done , approximately an hour']",
#   'dish_name': '7 up pound cake'},
#  {'id': '2923_11',
#   'question': 'What tags are associated with this dish?',
#   'section': 'tags',
#   'text': "The 7 up pound cake contains ['time-to-make', 'course', 'preparation', 'occasion', 'desserts', 'oven', 'easy', 'cakes', 'dietary', 'equipment', 'number-of-servings', '4-hours-or-less']",
#   'dish_name': '7 up pound cake'},
#  {'id': '2923_12',
#   'question': 'What is the rating of this dish?',
#   'section': 'rating',
#   'text': 'The 7 up pound cake has a rating of 0.',
#   'dish_name': '7 up pound cake'},
#  {'id': '2923_13',
#   'question': 'Can you provide a review?',
#   'section': 'review',
#   'text': "Review for 7 up pound cake: This is a great recipe that's too easy.",
#   'dish_name': '7 up pound cake'},
#  {'id': '2923_14',
#   'question': 'What category does this dish fall under?',
#   'section': 'category',
#   'text': 'The category of 7 up pound cake is bad.',
#   'dish_name': '7 up pound cake'},
#  {'id': '2923_15',
#   'question': 'What is the calorie status of this dish?',
#   'section': 'calorie_status',
#   'text': 'The calorie status of 7 up pound cake is High Calory.',
#   'dish_name': '7 up pound cake'},
#  {'id': '2923_16',
#   'question': 'What is the price of this dish?',
#   'section': 'price',
#   'text': 'The price of 7 up pound cake is $49.',
#   'dish_name': '7 up pound cake'},
#  {'id': '3091_1',
#   'question': 'What are the ingredients?',
#   'section': 'ingredients',
#   'text': "The kitty litter cake contains the following ingredients: ['spice cake mix', 'eggs', 'oil', 'water', 'white cake mix', 'vanilla instant pudding mix', 'cookies', 'green food coloring', 'tootsie rolls', 'new kitty litter box', 'pooper scooper']",
#   'dish_name': 'kitty litter cake'},
#  {'id': '3091_2',
#   'question': 'How many calories does it have?',
#   'section': 'calories',
#   'text': 'The kitty litter cake has 354.2 calories.',
#   'dish_name': 'kitty litter cake'},
#  {'id': '3091_3',
#   'question': 'How much total fat does it contain?',
#   'section': 'nutritional',
#   'text': 'The kitty litter cake has 23 grams of total fat (PDV).',
#   'dish_name': 'kitty litter cake'},
#  {'id': '3091_4',
#   'question': 'What is the sugar content?',
#   'section': 'nutritional',
#   'text': 'The kitty litter cake has 144 grams of sugar (PDV).',
#   'dish_name': 'kitty litter cake'},
#  {'id': '3091_5',
#   'question': 'How much sodium is in this dish?',
#   'section': 'nutritional',
#   'text': 'The kitty litter cake has 20 grams of sodium (PDV).',
#   'dish_name': 'kitty litter cake'},
#  {'id': '3091_6',
#   'question': 'What is the protein content?',
#   'section': 'nutritional',
#   'text': 'The kitty litter cake has 8 grams of protein (PDV).',
#   'dish_name': 'kitty litter cake'},
#  {'id': '3091_7',
#   'question': 'How much saturated fat is present?',
#   'section': 'nutritional',
#   'text': 'The kitty litter cake has 13 grams of saturated fat (PDV).',
#   'dish_name': 'kitty litter cake'},
#  {'id': '3091_8',
#   'question': 'What are the carbohydrate levels?',
#   'section': 'nutritional',
#   'text': 'The kitty litter cake has 16 grams of carbohydrates (PDV).',
#   'dish_name': 'kitty litter cake'},
#  {'id': '3091_9',
#   'question': 'How long does it take to prepare?',
#   'section': 'preparation',
#   'text': 'The kitty litter cake takes 60 minutes to prepare.',
#   'dish_name': 'kitty litter cake'},
#  {'id': '3091_10',
#   'question': 'What are the steps to prepare this dish?',
#   'section': 'steps',
#   'text': 'The kitty litter cake contains [\'prepare cake mixes and bake according to box directions\', \'prepare pudding , chill until ready to assemble\', \'crumble sandwich cookies in small batches in food processor , scraping often\', \'set aside all but 1 / 4 cup\', \'to the 1 / 4 cup of crumbs , add a few drops of green food coloring and mix using fork or shake in a jar\', \'when cakes are cooled to room temp , crumble into a large bowl\', \'toss with half the remaining cookie crumbs and chilled pudding\', \'you probably won\\\'t need all the pudding , mix the cake and "feel" it , you don\\\'t want it soggy , just moist\', \'ge ntly combine\', \'line litter box\', \'put mixture into box\', \'put 3 unwrapped tootsie rolls in microwave safe dish and heat until softened\', \'shape ends so they are no longer blunt , curving slightly\', \'repeat with 3 more tootsie rolls and bury in cake mixture\', \'sprinkle the other half of cookie crumbs over top\', \'scatter green crumbles lightly over top\', \'heat 3 tootsie rolls in microwave until almost melted\', \'scrape them on top of the cake and sprinkle with cookie crumbs\', \'spread remaining tootsie rolls over top\', \'take one and heat until pliable , hang over side of litter box , sprinkle with cookie crumbs\']',
#   'dish_name': 'kitty litter cake'},
#  {'id': '3091_11',
#   'question': 'What tags are associated with this dish?',
#   'section': 'tags',
#   'text': "The kitty litter cake contains ['60-minutes-or-less', 'time-to-make', 'course', 'preparation', 'for-large-groups', 'desserts', 'oven', 'cakes', 'dietary', 'equipment', 'number-of-servings']",
#   'dish_name': 'kitty litter cake'},
#  {'id': '3091_12',
#   'question': 'What is the rating of this dish?',
#   'section': 'rating',
#   'text': 'The kitty litter cake has a rating of 0.',
#   'dish_name': 'kitty litter cake'},
#  {'id': '3091_13',
#   'question': 'Can you provide a review?',
#   'section': 'review',
#   'text': 'Review for kitty litter cake: It probably tastes really good, but what a STRANGE recipe!!  LOL!!',
#   'dish_name': 'kitty litter cake'},
#  {'id': '3091_14',
#   'question': 'What category does this dish fall under?',
#   'section': 'category',
#   'text': 'The category of kitty litter cake is bad.',
#   'dish_name': 'kitty litter cake'},
#  {'id': '3091_15',
#   'question': 'What is the calorie status of this dish?',
#   'section': 'calorie_status',
#   'text': 'The calorie status of kitty litter cake is Low Calory.',
#   'dish_name': 'kitty litter cake'},
#  {'id': '3091_16',
#   'question': 'What is the price of this dish?',
#   'section': 'price',
#   'text': 'The price of kitty litter cake is $33.',
#   'dish_name': 'kitty litter cake'},
#  {'id': '3333_1',
#   'question': 'What are the ingredients?',
#   'section': 'ingredients',
#   'text': "The dirt cake ii contains the following ingredients: ['oreo cookies', 'butter', 'cream cheese', 'instant vanilla pudding', 'milk', 'cool whip', 'flower pot', 'artificial flower']",
#   'dish_name': 'dirt cake ii'},
#  {'id': '3333_2',
#   'question': 'How many calories does it have?',
#   'section': 'calories',
#   'text': 'The dirt cake ii has 578.5 calories.',
#   'dish_name': 'dirt cake ii'},
#  {'id': '3333_3',
#   'question': 'How much total fat does it contain?',
#   'section': 'nutritional',
#   'text': 'The dirt cake ii has 51 grams of total fat (PDV).',
#   'dish_name': 'dirt cake ii'},
#  {'id': '3333_4',
#   'question': 'What is the sugar content?',
#   'section': 'nutritional',
#   'text': 'The dirt cake ii has 196 grams of sugar (PDV).',
#   'dish_name': 'dirt cake ii'},
#  {'id': '3333_5',
#   'question': 'How much sodium is in this dish?',
#   'section': 'nutritional',
#   'text': 'The dirt cake ii has 31 grams of sodium (PDV).',
#   'dish_name': 'dirt cake ii'},
#  {'id': '3333_6',
#   'question': 'What is the protein content?',
#   'section': 'nutritional',
#   'text': 'The dirt cake ii has 13 grams of protein (PDV).',
#   'dish_name': 'dirt cake ii'},
#  {'id': '3333_7',
#   'question': 'How much saturated fat is present?',
#   'section': 'nutritional',
#   'text': 'The dirt cake ii has 97 grams of saturated fat (PDV).',
#   'dish_name': 'dirt cake ii'},
#  {'id': '3333_8',
#   'question': 'What are the carbohydrate levels?',
#   'section': 'nutritional',
#   'text': 'The dirt cake ii has 21 grams of carbohydrates (PDV).',
#   'dish_name': 'dirt cake ii'},
#  {'id': '3333_9',
#   'question': 'How long does it take to prepare?',
#   'section': 'preparation',
#   'text': 'The dirt cake ii takes 15 minutes to prepare.',
#   'dish_name': 'dirt cake ii'},
#  {'id': '3333_10',
#   'question': 'What are the steps to prepare this dish?',
#   'section': 'steps',
#   'text': "The dirt cake ii contains ['crush the oreo cookies in a blender or food processor', 'set aside', 'cream together butter or margarine and cream cheese', 'in a large bowl , mix 2 large boxes of vanilla instant pudding', 'add cream cheese mixture and 8 ounces of cool whip', 'beat together until mixed', 'in an 8 inch flower pot , layer the cookie mixture , the pudding mixture , the cookie mixture , and so on', 'end up with the cookie mixture', 'add an artificial flower on top']",
#   'dish_name': 'dirt cake ii'},
#  {'id': '3333_11',
#   'question': 'What tags are associated with this dish?',
#   'section': 'tags',
#   'text': "The dirt cake ii contains ['15-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'cuisine', 'preparation', 'occasion', 'north-american', 'desserts', 'american', 'kid-friendly', 'cakes', 'chocolate', 'dietary']",
#   'dish_name': 'dirt cake ii'},
#  {'id': '3333_12',
#   'question': 'What is the rating of this dish?',
#   'section': 'rating',
#   'text': 'The dirt cake ii has a rating of 5.',
#   'dish_name': 'dirt cake ii'},
#  {'id': '3333_13',
#   'question': 'Can you provide a review?',
#   'section': 'review',
#   'text': 'Review for dirt cake ii: This recipe is very tasty, and a big hit with the kids.  Make sure your cream cheese is soft before you mix it in or you\'ll have lumps.  If you don\'t have a flower pot on hand, a 9" deep dish pie pan works well,too.',
#   'dish_name': 'dirt cake ii'},
#  {'id': '3333_14',
#   'question': 'What category does this dish fall under?',
#   'section': 'category',
#   'text': 'The category of dirt cake ii is tasty.',
#   'dish_name': 'dirt cake ii'},
#  {'id': '3333_15',
#   'question': 'What is the calorie status of this dish?',
#   'section': 'calorie_status',
#   'text': 'The calorie status of dirt cake ii is High Calory.',
#   'dish_name': 'dirt cake ii'},
#  {'id': '3333_16',
#   'question': 'What is the price of this dish?',
#   'section': 'price',
#   'text': 'The price of dirt cake ii is $8.',
#   'dish_name': 'dirt cake ii'},
#  {'id': '3559_1',
#   'question': 'What are the ingredients?',
#   'section': 'ingredients',
#   'text': "The pumpkin bundt cake ii contains the following ingredients: ['yellow cake mix', 'instant butterscotch pudding mix', 'eggs', 'water', 'vegetable oil', 'canned pumpkin', 'pumpkin pie spice']",
#   'dish_name': 'pumpkin bundt cake ii'},
#  {'id': '3559_2',
#   'question': 'How many calories does it have?',
#   'section': 'calories',
#   'text': 'The pumpkin bundt cake ii has 193.9 calories.',
#   'dish_name': 'pumpkin bundt cake ii'},
#  {'id': '3559_3',
#   'question': 'How much total fat does it contain?',
#   'section': 'nutritional',
#   'text': 'The pumpkin bundt cake ii has 12 grams of total fat (PDV).',
#   'dish_name': 'pumpkin bundt cake ii'},
#  {'id': '3559_4',
#   'question': 'What is the sugar content?',
#   'section': 'nutritional',
#   'text': 'The pumpkin bundt cake ii has 58 grams of sugar (PDV).',
#   'dish_name': 'pumpkin bundt cake ii'},
#  {'id': '3559_5',
#   'question': 'How much sodium is in this dish?',
#   'section': 'nutritional',
#   'text': 'The pumpkin bundt cake ii has 11 grams of sodium (PDV).',
#   'dish_name': 'pumpkin bundt cake ii'},
#  {'id': '3559_6',
#   'question': 'What is the protein content?',
#   'section': 'nutritional',
#   'text': 'The pumpkin bundt cake ii has 6 grams of protein (PDV).',
#   'dish_name': 'pumpkin bundt cake ii'},
#  {'id': '3559_7',
#   'question': 'How much saturated fat is present?',
#   'section': 'nutritional',
#   'text': 'The pumpkin bundt cake ii has 7 grams of saturated fat (PDV).',
#   'dish_name': 'pumpkin bundt cake ii'},
#  {'id': '3559_8',
# ...
#  {'id': '12105_1',
#   'question': 'What are the ingredients?',
#   'section': 'ingredients',
#   'text': "The streusel plum cake contains the following ingredients: ['granulated sugar', 'soft margarine', 'eggs', 'all-purpose flour', 'baking powder', '2% low-fat milk', 'plums', 'brown sugar', 'cinnamon', 'icing sugar', 'milk', 'vanilla']",
#   'dish_name': 'streusel plum cake'},
#  {'id': '12105_2',
#   'question': 'How many calories does it have?',
#   'section': 'calories',
#   'text': 'The streusel plum cake has 277.3 calories.',
#   'dish_name': 'streusel plum cake'},
#  {'id': '12105_3',
#   'question': 'How much total fat does it contain?',
#   'section': 'nutritional',
#   'text': 'The streusel plum cake has 11 grams of total fat (PDV).',
#   'dish_name': 'streusel plum cake'},
#  {'id': '12105_4',
#   'question': 'What is the sugar content?',
#   'section': 'nutritional',
#   'text': 'The streusel plum cake has 137 grams of sugar (PDV).',
#   'dish_name': 'streusel plum cake'},
#  {'id': '12105_5',
#   'question': 'How much sodium is in this dish?',
#   'section': 'nutritional',
#   'text': 'The streusel plum cake has 4 grams of sodium (PDV).',
#   'dish_name': 'streusel plum cake'},
#  {'id': '12105_6',
#   'question': 'What is the protein content?',
#   'section': 'nutritional',
#   'text': 'The streusel plum cake has 8 grams of protein (PDV).',
#   'dish_name': 'streusel plum cake'},
#  {'id': '12105_7',
#   'question': 'How much saturated fat is present?',
#   'section': 'nutritional',
#   'text': 'The streusel plum cake has 6 grams of saturated fat (PDV).',
#   'dish_name': 'streusel plum cake'},
#  {'id': '12105_8',
#   'question': 'What are the carbohydrate levels?',
#   'section': 'nutritional',
#   'text': 'The streusel plum cake has 16 grams of carbohydrates (PDV).',
#   'dish_name': 'streusel plum cake'},
#  {'id': '12105_9',
#   'question': 'How long does it take to prepare?',
#   'section': 'preparation',
#   'text': 'The streusel plum cake takes 60 minutes to prepare.',
#   'dish_name': 'streusel plum cake'},
#  {'id': '12105_10',
#   'question': 'What are the steps to prepare this dish?',
#   'section': 'steps',
#   'text': "The streusel plum cake contains ['in a large bowl , cream together sugar , margarine and egg yolks until fluffy', 'combine flour with baking powder', 'beat into egg mixture alternately with milk', 'beat egg whites until stiff but not dry', 'fold into batter', 'pour batter into greased 9 inch square cake pan', 'halve and pit plums', 'arrange over batter', 'streusel topping-------------', 'in a small bowl , combine brown sugar , margarine and cinnamon', 'sprinkle over fruit', 'bake in 350f oven for 35-45 minutes or until top is golden and tester inserted into centre of cake comes out clean', 'glaze --------------', 'combine icing sugar , milk and vanilla', 'drizzle over cooled cake']",
#   'dish_name': 'streusel plum cake'},
#  {'id': '12105_11',
#   'question': 'What tags are associated with this dish?',
#   'section': 'tags',
#   'text': "The streusel plum cake contains ['60-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'cuisine', 'preparation', 'occasion', 'north-american', 'low-protein', 'healthy', 'breads', 'desserts', 'fruit', 'american', 'canadian', 'oven', 'easy', 'diabetic', 'dinner-party', 'cakes', 'coffee-cakes', 'dietary', 'low-sodium', 'low-saturated-fat', 'comfort-food', 'pacific-northwest', 'low-in-something', 'taste-mood', 'equipment']",
#   'dish_name': 'streusel plum cake'},
#  {'id': '12105_12',
#   'question': 'What is the rating of this dish?',
#   'section': 'rating',
#   'text': 'The streusel plum cake has a rating of 5.',
#   'dish_name': 'streusel plum cake'},
#  {'id': '12105_13',
#   'question': 'Can you provide a review?',
#   'section': 'review',
#   'text': "Review for streusel plum cake: Five stars isn't enough for this recipe! You have brought back a wonderful childhood memory for me.  When I was a child I lived next to a man who was a professional baker and when plums were in season he made something very similar to your recipe and it was my favorite.  I've been wanting it ever since and now I've found it thanks to you. I made it tonight for my Mother's 88th Birthday and it was a five star sensation!!",
#   'dish_name': 'streusel plum cake'},
#  {'id': '12105_14',
#   'question': 'What category does this dish fall under?',
#   'section': 'category',
#   'text': 'The category of streusel plum cake is tasty.',
#   'dish_name': 'streusel plum cake'},
#  {'id': '12105_15',
#   'question': 'What is the calorie status of this dish?',
#   'section': 'calorie_status',
#   'text': 'The calorie status of streusel plum cake is Low Calory.',
#   'dish_name': 'streusel plum cake'},
#  {'id': '12105_16',
#   'question': 'What is the price of this dish?',
#   'section': 'price',
#   'text': 'The price of streusel plum cake is $21.',
#   'dish_name': 'streusel plum cake'},
#  {'id': '12166_1',
#   'question': 'What are the ingredients?',
#   'section': 'ingredients',
#   'text': "The coffee cake over night contains the following ingredients: ['flour', 'sugar', 'brown sugar', 'shortening', 'buttermilk', 'baking powder', 'cinnamon', 'salt', 'eggs', 'baking soda', 'granulated sugar', 'nuts']",
#   'dish_name': 'coffee cake over night'},
#  {'id': '12166_2',
#   'question': 'How many calories does it have?',
#   'section': 'calories',
#   'text': 'The coffee cake over night has 577.4 calories.',
#   'dish_name': 'coffee cake over night'},
#  {'id': '12166_3',
#   'question': 'How much total fat does it contain?',
#   'section': 'nutritional',
#   'text': 'The coffee cake over night has 31 grams of total fat (PDV).',
#   'dish_name': 'coffee cake over night'},
#  {'id': '12166_4',
#   'question': 'What is the sugar content?',
#   'section': 'nutritional',
#   'text': 'The coffee cake over night has 282 grams of sugar (PDV).',
#   'dish_name': 'coffee cake over night'},
#  {'id': '12166_5',
#   'question': 'How much sodium is in this dish?',
#   'section': 'nutritional',
#   'text': 'The coffee cake over night has 14 grams of sodium (PDV).',
#   'dish_name': 'coffee cake over night'},
#  {'id': '12166_6',
#   'question': 'What is the protein content?',
#   'section': 'nutritional',
#   'text': 'The coffee cake over night has 13 grams of protein (PDV).',
#   'dish_name': 'coffee cake over night'},
#  {'id': '12166_7',
#   'question': 'How much saturated fat is present?',
#   'section': 'nutritional',
#   'text': 'The coffee cake over night has 24 grams of saturated fat (PDV).',
#   'dish_name': 'coffee cake over night'},
#  {'id': '12166_8',
#   'question': 'What are the carbohydrate levels?',
#   'section': 'nutritional',
#   'text': 'The coffee cake over night has 31 grams of carbohydrates (PDV).',
#   'dish_name': 'coffee cake over night'},
#  {'id': '12166_9',
#   'question': 'How long does it take to prepare?',
#   'section': 'preparation',
#   'text': 'The coffee cake over night takes 60 minutes to prepare.',
#   'dish_name': 'coffee cake over night'},
#  {'id': '12166_10',
#   'question': 'What are the steps to prepare this dish?',
#   'section': 'steps',
#   'text': "The coffee cake over night contains ['grease 9x13 pan', 'in large bowl mix flour , sugar , brown sugar , shortening , buttermilk , soda , baking powder , cinnamon , salt , and eggs', 'blend on low speed of mixer', 'in small bowl mix brown sugar , granulated sugar , cinnamon , and nuts', 'pour half of the cake batter into pan', 'sprinkle half of the topping mix over', 'repeat a second time', 'cover and refrigerate overnight', 'pre-heat oven to 350f', 'bake at 350f for 30-40 minutes']",
#   'dish_name': 'coffee cake over night'},
#  {'id': '12166_11',
#   'question': 'What tags are associated with this dish?',
#   'section': 'tags',
#   'text': "The coffee cake over night contains ['60-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'preparation', 'occasion', 'breads', 'breakfast', 'lunch', 'fruit', 'oven', 'holiday-event', 'winter', 'coffee-cakes', 'nuts', 'grains', 'dietary', 'christmas', 'seasonal', 'pasta-rice-and-grains', 'equipment']",
#   'dish_name': 'coffee cake over night'},
#  {'id': '12166_12',
#   'question': 'What is the rating of this dish?',
#   'section': 'rating',
#   'text': 'The coffee cake over night has a rating of 5.',
#   'dish_name': 'coffee cake over night'},
#  {'id': '12166_13',
#   'question': 'Can you provide a review?',
#   'section': 'review',
#   'text': "Review for coffee cake over night: This was so good! Very easy to make. The only thing I did to this recipe was increase the cinnamon by 1/2 t in the batter. Couldn't wait for it to come out of the oven in the morning.",
#   'dish_name': 'coffee cake over night'},
#  {'id': '12166_14',
#   'question': 'What category does this dish fall under?',
#   'section': 'category',
#   'text': 'The category of coffee cake over night is tasty.',
#   'dish_name': 'coffee cake over night'},
#  {'id': '12166_15',
#   'question': 'What is the calorie status of this dish?',
#   'section': 'calorie_status',
#   'text': 'The calorie status of coffee cake over night is High Calory.',
#   'dish_name': 'coffee cake over night'},
#  {'id': '12166_16',
#   'question': 'What is the price of this dish?',
#   'section': 'price',
#   'text': 'The price of coffee cake over night is $49.',
#   'dish_name': 'coffee cake over night'},
#  {'id': '12313_1',
#   'question': 'What are the ingredients?',
#   'section': 'ingredients',
#   'text': "The depression fudge cake contains the following ingredients: ['sugar', 'buttermilk', 'flour', 'baking soda', 'salt', 'vanilla', 'cocoa', 'butter', 'powdered sugar', 'hot water']",
#   'dish_name': 'depression fudge cake'},
#  {'id': '12313_2',
#   'question': 'How many calories does it have?',
#   'section': 'calories',
#   'text': 'The depression fudge cake has 271.6 calories.',
#   'dish_name': 'depression fudge cake'},
#  {'id': '12313_3',
#   'question': 'How much total fat does it contain?',
#   'section': 'nutritional',
#   'text': 'The depression fudge cake has 10 grams of total fat (PDV).',
#   'dish_name': 'depression fudge cake'},
#  {'id': '12313_4',
#   'question': 'What is the sugar content?',
#   'section': 'nutritional',
#   'text': 'The depression fudge cake has 149 grams of sugar (PDV).',
#   'dish_name': 'depression fudge cake'},
#  {'id': '12313_5',
#   'question': 'How much sodium is in this dish?',
#   'section': 'nutritional',
#   'text': 'The depression fudge cake has 11 grams of sodium (PDV).',
#   'dish_name': 'depression fudge cake'},
#  {'id': '12313_6',
#   'question': 'What is the protein content?',
#   'section': 'nutritional',
#   'text': 'The depression fudge cake has 5 grams of protein (PDV).',
#   'dish_name': 'depression fudge cake'},
#  {'id': '12313_7',
#   'question': 'How much saturated fat is present?',
#   'section': 'nutritional',
#   'text': 'The depression fudge cake has 20 grams of saturated fat (PDV).',
#   'dish_name': 'depression fudge cake'},
#  {'id': '12313_8',
#   'question': 'What are the carbohydrate levels?',
#   'section': 'nutritional',
#   'text': 'The depression fudge cake has 16 grams of carbohydrates (PDV).',
#   'dish_name': 'depression fudge cake'},
#  {'id': '12313_9',
#   'question': 'How long does it take to prepare?',
#   'section': 'preparation',
#   'text': 'The depression fudge cake takes 35 minutes to prepare.',
#   'dish_name': 'depression fudge cake'},
#  {'id': '12313_10',
#   'question': 'What are the steps to prepare this dish?',
#   'section': 'steps',
#   'text': "The depression fudge cake contains ['melt cocoa and butter', 'put soda in buttermilk', 'mix dry ingredients first and add cocoa last', 'bake in a greased and floured 8 in', 'pan for 25 min at 350f degrees', '-------cocoa frosting--------', 'mix sugar and water', 'add softened butter and cocoa', 'beat until creamy', 'add 1 tsp vanilla', 'stir until smooth and ice cake']",
#   'dish_name': 'depression fudge cake'},
#  {'id': '12313_11',
#   'question': 'What tags are associated with this dish?',
#   'section': 'tags',
#   'text': "The depression fudge cake contains ['60-minutes-or-less', 'time-to-make', 'course', 'cuisine', 'preparation', 'north-american', 'healthy', 'desserts', 'american', 'southern-united-states', 'oven', 'easy', 'cakes', 'dietary', 'equipment']",
#   'dish_name': 'depression fudge cake'},
#  {'id': '12313_12',
#   'question': 'What is the rating of this dish?',
#   'section': 'rating',
#   'text': 'The depression fudge cake has a rating of 5.',
#   'dish_name': 'depression fudge cake'},
#  {'id': '12313_13',
#   'question': 'Can you provide a review?',
#   'section': 'review',
#   'text': 'Review for depression fudge cake: Oh well, it is so good! I wished while I was baking this cake that I were a spoon or bowl in which the ingredients were mixed by me to make it.\r\nI used 1 cup (minus 1 tbsp) of Fresh milk and added 1 tbsp of lemon juice instead of the buttermilk. Rest of the things I have stuck to this recipe. It\'s a very nice cake and quite easy too. The fact that it is eggless makes it all the more nice as many people I know don\'t have eggs at all, hence, I have many more soon going to be "lovers" of this cake! I\'d say that if your depressed or low, request mom to make this for u if u love cakes n chocolate - Just put in 1 piece  of cake and watch your depression run away for miles from you:) Last but not the least, I loved the deep dark brown colour of the cake when done. I garnished it with some chopped almonds and maraschino cherries that made it look all the more yummy and mouth watering and oh well, my stomach says "Give me more of Depression Fudge cake now and NOW means NOWWWWWW"!!!:)',
#   'dish_name': 'depression fudge cake'},
#  {'id': '12313_14',
#   'question': 'What category does this dish fall under?',
#   'section': 'category',
#   'text': 'The category of depression fudge cake is tasty.',
#   'dish_name': 'depression fudge cake'},
#  {'id': '12313_15',
#   'question': 'What is the calorie status of this dish?',
#   'section': 'calorie_status',
#   'text': 'The calorie status of depression fudge cake is Low Calory.',
#   'dish_name': 'depression fudge cake'},
#  {'id': '12313_16',
#   'question': 'What is the price of this dish?',
#   'section': 'price',
#   'text': 'The price of depression fudge cake is $22.',
#   'dish_name': 'depression fudge cake'},
#  {'id': '12564_1',
#   'question': 'What are the ingredients?',
#   'section': 'ingredients',
#   'text': "The egg free milk free chocolate cake contains the following ingredients: ['all-purpose flour', 'white sugar', 'cocoa', 'baking soda', 'baking powder', 'salt', 'canola oil', 'white vinegar', 'pure vanilla extract', 'water']",
#   'dish_name': 'egg free milk free chocolate cake'},
#  {'id': '12564_2',
#   'question': 'How many calories does it have?',
#   'section': 'calories',
#   'text': 'The egg free milk free chocolate cake has 324.7 calories.',
#   'dish_name': 'egg free milk free chocolate cake'},
#  {'id': '12564_3',
#   'question': 'How much total fat does it contain?',
#   'section': 'nutritional',
#   'text': 'The egg free milk free chocolate cake has 19 grams of total fat (PDV).',
#   'dish_name': 'egg free milk free chocolate cake'},
#  {'id': '12564_4',
#   'question': 'What is the sugar content?',
#   'section': 'nutritional',
#   'text': 'The egg free milk free chocolate cake has 133 grams of sugar (PDV).',
#   'dish_name': 'egg free milk free chocolate cake'},
#  {'id': '12564_5',
#   'question': 'How much sodium is in this dish?',
#   'section': 'nutritional',
#   'text': 'The egg free milk free chocolate cake has 19 grams of sodium (PDV).',
#   'dish_name': 'egg free milk free chocolate cake'},
#  {'id': '12564_6',
#   'question': 'What is the protein content?',
#   'section': 'nutritional',
#   'text': 'The egg free milk free chocolate cake has 5 grams of protein (PDV).',
#   'dish_name': 'egg free milk free chocolate cake'},
#  {'id': '12564_7',
#   'question': 'How much saturated fat is present?',
#   'section': 'nutritional',
#   'text': 'The egg free milk free chocolate cake has 4 grams of saturated fat (PDV).',
#   'dish_name': 'egg free milk free chocolate cake'},
#  {'id': '12564_8',
#   'question': 'What are the carbohydrate levels?',
#   'section': 'nutritional',
#   'text': 'The egg free milk free chocolate cake has 17 grams of carbohydrates (PDV).',
#   'dish_name': 'egg free milk free chocolate cake'},
#  ...]
